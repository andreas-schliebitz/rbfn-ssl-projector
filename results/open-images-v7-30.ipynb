# %% [markdown]
# # OpenImagesV7-30

# %%
import shap
import pandas as pd
import numpy as np

from pathlib import Path
from xgboost import XGBRegressor

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
DATASET_NAME = "open-images-v7-30"
METRICS = ["test_MulticlassAccuracy", "test_MulticlassF1Score", "test_MulticlassPrecision", "test_MulticlassRecall"]
MAIN_METRIC = "test_MulticlassAccuracy"

# %%
RESULTS_PATH = Path(".").resolve()

# %% [markdown]
# ## Default Projector

# %%
DEFAULT_EVAL_RESULTS_PATH = RESULTS_PATH.joinpath(DATASET_NAME, "default", f"rbfn-ssl-projector-default-eval_{DATASET_NAME}.csv")
print(DEFAULT_EVAL_RESULTS_PATH)
DEFAULT_RANGES = [
    "architecture",
    "projection_head_num_layers"
]
# Out:
# /cluster/user/aschlieb/promotion/code/rbfn-ssl-projector/results/open-images-v7-30/default/rbfn-ssl-projector-default-eval_open-images-v7-30.csv

# %%
df_default = pd.read_csv(DEFAULT_EVAL_RESULTS_PATH)
df_default = df_default[["projection_head_type"] + DEFAULT_RANGES + METRICS]

# %% [markdown]
# ### By Architecture

# %% [markdown]
# #### SimCLR

# %%
df_default_simclr = df_default[df_default["architecture"] == "simclr"]
df_default_simclr = df_default_simclr.sort_values(by=MAIN_METRIC, ascending=False)
df_default_simclr
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 7              default       simclr                           3
# 8              default       simclr                           2
# 6              default       simclr                           4
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 7                 0.667250                0.660157                  0.665730
# 8                 0.659627                0.654425                  0.662019
# 6                 0.652607                0.644223                  0.654069
#
#    test_MulticlassRecall
# 7               0.667250
# 8               0.659627
# 6               0.652607

# %% [markdown]
# #### SimSiam

# %%
df_default_simsiam = df_default[df_default["architecture"] == "simsiam"]
df_default_simsiam = df_default_simsiam.sort_values(by=MAIN_METRIC, ascending=False)
df_default_simsiam
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 5              default      simsiam                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 5                 0.689633                0.678074                  0.683768
#
#    test_MulticlassRecall
# 5               0.689633

# %% [markdown]
# #### MoCo

# %%
df_default_moco = df_default[df_default["architecture"] == "moco"]
df_default_moco = df_default_moco.sort_values(by=MAIN_METRIC, ascending=False)
df_default_moco
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 2              default         moco                           4
# 3              default         moco                           3
# 4              default         moco                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 2                 0.706176                0.698566                  0.706860
# 3                 0.703754                0.696334                  0.704957
# 4                 0.702031                0.694477                  0.702996
#
#    test_MulticlassRecall
# 2               0.706176
# 3               0.703754
# 4               0.702031

# %% [markdown]
# #### BYOL

# %%
df_default_byol = df_default[df_default["architecture"] == "byol"]
df_default_byol = df_default_byol.sort_values(by=MAIN_METRIC, ascending=False)
df_default_byol
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 1              default         byol                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 1                 0.647984                0.623352                  0.691118
#
#    test_MulticlassRecall
# 1               0.647984

# %% [markdown]
# #### SwAV

# %%
df_default_swav = df_default[df_default["architecture"] == "swav"]
df_default_swav = df_default_swav.sort_values(by=MAIN_METRIC, ascending=False)
df_default_swav
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 0              default         swav                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 0                 0.648224                0.626675                  0.658935
#
#    test_MulticlassRecall
# 0               0.648224

# %% [markdown]
# ## RBFN Projector

# %%
RBFN_EVAL_RESULTS_PATH = RESULTS_PATH.joinpath(DATASET_NAME, "rbfn", f"rbfn-ssl-projector-rbfn-eval_{DATASET_NAME}.csv")
print(RBFN_EVAL_RESULTS_PATH)

RBFN_RANGES = [
    "architecture",
    "projection_head_num_layers",
    "rbfn_projection_head_num_kernels",
    "rbfn_projection_head_radial_function",
    "rbfn_projection_head_normalize"
]
# Out:
# /cluster/user/aschlieb/promotion/code/rbfn-ssl-projector/results/open-images-v7-30/rbfn/rbfn-ssl-projector-rbfn-eval_open-images-v7-30.csv

# %% [markdown]
# ### By Architecture

# %%
df_rbfn = pd.read_csv(RBFN_EVAL_RESULTS_PATH)
df_rbfn = df_rbfn[["projection_head_type"] + RBFN_RANGES + METRICS]

# %% [markdown]
# #### SimCLR

# %%
df_rbfn_simclr = df_rbfn[df_rbfn["architecture"] == "simclr"]
df_rbfn_simclr = df_rbfn_simclr.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_simclr
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 144                 rbfn       simclr                           4
# 151                 rbfn       simclr                           4
# 150                 rbfn       simclr                           4
# 167                 rbfn       simclr                           4
# 160                 rbfn       simclr                           4
# 158                 rbfn       simclr                           4
# 159                 rbfn       simclr                           4
# 152                 rbfn       simclr                           4
# 206                 rbfn       simclr                           2
# 207                 rbfn       simclr                           2
# 215                 rbfn       simclr                           2
# 214                 rbfn       simclr                           2
# 198                 rbfn       simclr                           2
# 166                 rbfn       simclr                           4
# 175                 rbfn       simclr                           3
# 174                 rbfn       simclr                           3
# 182                 rbfn       simclr                           3
# 183                 rbfn       simclr                           3
# 191                 rbfn       simclr                           3
# 190                 rbfn       simclr                           3
# 199                 rbfn       simclr                           2
# 200                 rbfn       simclr                           2
# 192                 rbfn       simclr                           2
# 208                 rbfn       simclr                           2
# 202                 rbfn       simclr                           2
# 194                 rbfn       simclr                           2
# 210                 rbfn       simclr                           2
# 193                 rbfn       simclr                           2
# 163                 rbfn       simclr                           4
# 165                 rbfn       simclr                           4
# 196                 rbfn       simclr                           2
# 204                 rbfn       simclr                           2
# 197                 rbfn       simclr                           2
# 212                 rbfn       simclr                           2
# 195                 rbfn       simclr                           2
# 155                 rbfn       simclr                           4
# 157                 rbfn       simclr                           4
# 147                 rbfn       simclr                           4
# 149                 rbfn       simclr                           4
# 201                 rbfn       simclr                           2
# 205                 rbfn       simclr                           2
# 209                 rbfn       simclr                           2
# 203                 rbfn       simclr                           2
# 168                 rbfn       simclr                           3
# 178                 rbfn       simclr                           3
# 170                 rbfn       simclr                           3
# 161                 rbfn       simclr                           4
# 153                 rbfn       simclr                           4
# 176                 rbfn       simclr                           3
# 186                 rbfn       simclr                           3
# 184                 rbfn       simclr                           3
# 145                 rbfn       simclr                           4
# 173                 rbfn       simclr                           3
# 169                 rbfn       simclr                           3
# 187                 rbfn       simclr                           3
# 146                 rbfn       simclr                           4
# 148                 rbfn       simclr                           4
# 154                 rbfn       simclr                           4
# 156                 rbfn       simclr                           4
# 177                 rbfn       simclr                           3
# 172                 rbfn       simclr                           3
# 180                 rbfn       simclr                           3
# 162                 rbfn       simclr                           4
# 164                 rbfn       simclr                           4
# 211                 rbfn       simclr                           2
# 188                 rbfn       simclr                           3
# 213                 rbfn       simclr                           2
# 185                 rbfn       simclr                           3
# 189                 rbfn       simclr                           3
# 181                 rbfn       simclr                           3
# 179                 rbfn       simclr                           3
# 171                 rbfn       simclr                           3
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 144                               128                                  tps
# 151                               128                             gaussian
# 150                               128                             gaussian
# 167                               512                             gaussian
# 160                               512                                  tps
# 158                               256                             gaussian
# 159                               256                             gaussian
# 152                               256                                  tps
# 206                               256                             gaussian
# 207                               256                             gaussian
# 215                               512                             gaussian
# 214                               512                             gaussian
# 198                               128                             gaussian
# 166                               512                             gaussian
# 175                               128                             gaussian
# 174                               128                             gaussian
# 182                               256                             gaussian
# 183                               256                             gaussian
# 191                               512                             gaussian
# 190                               512                             gaussian
# 199                               128                             gaussian
# 200                               256                                  tps
# 192                               128                                  tps
# 208                               512                                  tps
# 202                               256                         multiquadric
# 194                               128                         multiquadric
# 210                               512                         multiquadric
# 193                               128                                  tps
# 163                               512                         multiquadric
# 165                               512                 inverse_multiquadric
# 196                               128                 inverse_multiquadric
# 204                               256                 inverse_multiquadric
# 197                               128                 inverse_multiquadric
# 212                               512                 inverse_multiquadric
# 195                               128                         multiquadric
# 155                               256                         multiquadric
# 157                               256                 inverse_multiquadric
# 147                               128                         multiquadric
# 149                               128                 inverse_multiquadric
# 201                               256                                  tps
# 205                               256                 inverse_multiquadric
# 209                               512                                  tps
# 203                               256                         multiquadric
# 168                               128                                  tps
# 178                               256                         multiquadric
# 170                               128                         multiquadric
# 161                               512                                  tps
# 153                               256                                  tps
# 176                               256                                  tps
# 186                               512                         multiquadric
# 184                               512                                  tps
# 145                               128                                  tps
# 173                               128                 inverse_multiquadric
# 169                               128                                  tps
# 187                               512                         multiquadric
# 146                               128                         multiquadric
# 148                               128                 inverse_multiquadric
# 154                               256                         multiquadric
# 156                               256                 inverse_multiquadric
# 177                               256                                  tps
# 172                               128                 inverse_multiquadric
# 180                               256                 inverse_multiquadric
# 162                               512                         multiquadric
# 164                               512                 inverse_multiquadric
# 211                               512                         multiquadric
# 188                               512                 inverse_multiquadric
# 213                               512                 inverse_multiquadric
# 185                               512                                  tps
# 189                               512                 inverse_multiquadric
# 181                               256                 inverse_multiquadric
# 179                               256                         multiquadric
# 171                               128                         multiquadric
#
#      rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 144                           False                 0.657795
# 151                            True                 0.657795
# 150                           False                 0.657795
# 167                            True                 0.657795
# 160                           False                 0.657795
# 158                           False                 0.657795
# 159                            True                 0.657795
# 152                           False                 0.657795
# 206                           False                 0.657795
# 207                            True                 0.657795
# 215                            True                 0.657795
# 214                           False                 0.657795
# 198                           False                 0.657795
# 166                           False                 0.657795
# 175                            True                 0.657795
# 174                           False                 0.657795
# 182                           False                 0.657795
# 183                            True                 0.657795
# 191                            True                 0.657795
# 190                           False                 0.657795
# 199                            True                 0.657795
# 200                           False                 0.649119
# 192                           False                 0.635653
# 208                           False                 0.623380
# 202                           False                 0.613646
# 194                           False                 0.610617
# 210                           False                 0.603246
# 193                            True                 0.580389
# 163                            True                 0.569925
# 165                            True                 0.561121
# 196                           False                 0.547956
# 204                           False                 0.546286
# 197                            True                 0.541672
# 212                           False                 0.540935
# 195                            True                 0.524836
# 155                            True                 0.519928
# 157                            True                 0.517536
# 147                            True                 0.513964
# 149                            True                 0.512315
# 201                            True                 0.506916
# 205                            True                 0.462395
# 209                            True                 0.461361
# 203                            True                 0.459665
# 168                           False                 0.423146
# 178                           False                 0.415096
# 170                           False                 0.410189
# 161                            True                 0.400953
# 153                            True                 0.372383
# 176                           False                 0.339228
# 186                           False                 0.304937
# 184                           False                 0.301191
# 145                            True                 0.240571
# 173                            True                 0.075639
# 169                            True                 0.034503
# 187                            True                 0.033918
# 146                           False                 0.033333
# 148                           False                 0.033333
# 154                           False                 0.033333
# 156                           False                 0.033333
# 177                            True                 0.033333
# 172                           False                 0.033333
# 180                           False                 0.033333
# 162                           False                 0.033333
# 164                           False                 0.033333
# 211                            True                 0.033333
# 188                           False                 0.033333
# 213                            True                 0.033333
# 185                            True                 0.033333
# 189                            True                 0.031579
# 181                            True                 0.030994
# 179                            True                 0.029240
# 171                            True                 0.023960
#
#      test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 144                0.635867                  0.668911               0.657795
# 151                0.635867                  0.668911               0.657795
# 150                0.635867                  0.668911               0.657795
# 167                0.635867                  0.668911               0.657795
# 160                0.635867                  0.668911               0.657795
# 158                0.635867                  0.668911               0.657795
# 159                0.635867                  0.668911               0.657795
# 152                0.635867                  0.668911               0.657795
# 206                0.635867                  0.668911               0.657795
# 207                0.635867                  0.668911               0.657795
# 215                0.635867                  0.668911               0.657795
# 214                0.635867                  0.668911               0.657795
# 198                0.635867                  0.668911               0.657795
# 166                0.635867                  0.668911               0.657795
# 175                0.635867                  0.668911               0.657795
# 174                0.635867                  0.668911               0.657795
# 182                0.635867                  0.668911               0.657795
# 183                0.635867                  0.668911               0.657795
# 191                0.635867                  0.668911               0.657795
# 190                0.635867                  0.668911               0.657795
# 199                0.635867                  0.668911               0.657795
# 200                0.640934                  0.647608               0.649119
# 192                0.627658                  0.630872               0.635653
# 208                0.606685                  0.608251               0.623380
# 202                0.598318                  0.602628               0.613646
# 194                0.598498                  0.601627               0.610617
# 210                0.581374                  0.584401               0.603246
# 193                0.568841                  0.584044               0.580389
# 163                0.535321                  0.592083               0.569925
# 165                0.527622                  0.583742               0.561121
# 196                0.516530                  0.525145               0.547956
# 204                0.517823                  0.538819               0.546286
# 197                0.513937                  0.530529               0.541672
# 212                0.505590                  0.543181               0.540935
# 195                0.504143                  0.530646               0.524836
# 155                0.483127                  0.533661               0.519928
# 157                0.479852                  0.536855               0.517536
# 147                0.478566                  0.524471               0.513964
# 149                0.476316                  0.530295               0.512315
# 201                0.487271                  0.502753               0.506916
# 205                0.426060                  0.461398               0.462395
# 209                0.429234                  0.455448               0.461361
# 203                0.421200                  0.441194               0.459665
# 168                0.361395                  0.391101               0.423146
# 178                0.356976                  0.428310               0.415096
# 170                0.370097                  0.404328               0.410189
# 161                0.356865                  0.389369               0.400953
# 153                0.337979                  0.393136               0.372383
# 176                0.299919                  0.394504               0.339228
# 186                0.227623                  0.265927               0.304937
# 184                0.255566                  0.375166               0.301191
# 145                0.215564                  0.295890               0.240571
# 173                0.047752                  0.086989               0.075639
# 169                0.006190                  0.003462               0.034503
# 187                0.006032                  0.003405               0.033918
# 146                0.002163                  0.001118               0.033333
# 148                0.002163                  0.001118               0.033333
# 154                0.002163                  0.001118               0.033333
# 156                0.002163                  0.001118               0.033333
# 177                0.002164                  0.001118               0.033333
# 172                0.002163                  0.001118               0.033333
# 180                0.002163                  0.001118               0.033333
# 162                0.002163                  0.001118               0.033333
# 164                0.002163                  0.001118               0.033333
# 211                0.002163                  0.001118               0.033333
# 188                0.002163                  0.001118               0.033333
# 213                0.002163                  0.001118               0.033333
# 185                0.002164                  0.001118               0.033333
# 189                0.005592                  0.003110               0.031579
# 181                0.005544                  0.003071               0.030994
# 179                0.005188                  0.002872               0.029240
# 171                0.010571                  0.009367               0.023960

# %% [markdown]
# #### SimSiam

# %%
df_rbfn_simsiam = df_rbfn[df_rbfn["architecture"] == "simsiam"]
df_rbfn_simsiam = df_rbfn_simsiam.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_simsiam
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 122                 rbfn      simsiam                           2
# 138                 rbfn      simsiam                           2
# 123                 rbfn      simsiam                           2
# 121                 rbfn      simsiam                           2
# 127                 rbfn      simsiam                           2
# 126                 rbfn      simsiam                           2
# 129                 rbfn      simsiam                           2
# 125                 rbfn      simsiam                           2
# 143                 rbfn      simsiam                           2
# 142                 rbfn      simsiam                           2
# 134                 rbfn      simsiam                           2
# 131                 rbfn      simsiam                           2
# 135                 rbfn      simsiam                           2
# 139                 rbfn      simsiam                           2
# 137                 rbfn      simsiam                           2
# 133                 rbfn      simsiam                           2
# 141                 rbfn      simsiam                           2
# 130                 rbfn      simsiam                           2
# 124                 rbfn      simsiam                           2
# 132                 rbfn      simsiam                           2
# 140                 rbfn      simsiam                           2
# 120                 rbfn      simsiam                           2
# 128                 rbfn      simsiam                           2
# 136                 rbfn      simsiam                           2
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 122                               128                         multiquadric
# 138                               512                         multiquadric
# 123                               128                         multiquadric
# 121                               128                                  tps
# 127                               128                             gaussian
# 126                               128                             gaussian
# 129                               256                                  tps
# 125                               128                 inverse_multiquadric
# 143                               512                             gaussian
# 142                               512                             gaussian
# 134                               256                             gaussian
# 131                               256                         multiquadric
# 135                               256                             gaussian
# 139                               512                         multiquadric
# 137                               512                                  tps
# 133                               256                 inverse_multiquadric
# 141                               512                 inverse_multiquadric
# 130                               256                         multiquadric
# 124                               128                 inverse_multiquadric
# 132                               256                 inverse_multiquadric
# 140                               512                 inverse_multiquadric
# 120                               128                                  tps
# 128                               256                                  tps
# 136                               512                                  tps
#
#      rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 122                           False                 0.669576
# 138                           False                 0.669576
# 123                            True                 0.669011
# 121                            True                 0.669011
# 127                            True                 0.669011
# 126                           False                 0.669011
# 129                            True                 0.669011
# 125                            True                 0.669011
# 143                            True                 0.669011
# 142                           False                 0.669011
# 134                           False                 0.669011
# 131                            True                 0.669011
# 135                            True                 0.669011
# 139                            True                 0.669011
# 137                            True                 0.669011
# 133                            True                 0.669011
# 141                            True                 0.669011
# 130                           False                 0.668980
# 124                           False                 0.668426
# 132                           False                 0.667841
# 140                           False                 0.667256
# 120                           False                 0.666549
# 128                           False                 0.664199
# 136                           False                 0.661828
#
#      test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 122                0.647635                  0.678805               0.669576
# 138                0.647626                  0.679128               0.669576
# 123                0.646160                  0.680040               0.669011
# 121                0.646160                  0.680040               0.669011
# 127                0.646160                  0.680040               0.669011
# 126                0.646160                  0.680040               0.669011
# 129                0.646160                  0.680040               0.669011
# 125                0.646160                  0.680040               0.669011
# 143                0.646160                  0.680040               0.669011
# 142                0.646160                  0.680040               0.669011
# 134                0.646160                  0.680040               0.669011
# 131                0.646160                  0.680040               0.669011
# 135                0.646160                  0.680040               0.669011
# 139                0.646160                  0.680040               0.669011
# 137                0.646160                  0.680040               0.669011
# 133                0.646160                  0.680040               0.669011
# 141                0.646160                  0.680040               0.669011
# 130                0.647067                  0.680329               0.668980
# 124                0.645530                  0.678971               0.668426
# 132                0.644875                  0.678369               0.667841
# 140                0.644147                  0.678564               0.667256
# 120                0.645506                  0.672062               0.666549
# 128                0.643414                  0.668422               0.664199
# 136                0.641648                  0.665745               0.661828

# %% [markdown]
# #### MoCo

# %%
df_rbfn_moco = df_rbfn[df_rbfn["architecture"] == "moco"]
df_rbfn_moco = df_rbfn_moco.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_moco
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 116                 rbfn         moco                           2
# 51                  rbfn         moco                           4
# 106                 rbfn         moco                           2
# 53                  rbfn         moco                           4
# 114                 rbfn         moco                           2
# 112                 rbfn         moco                           2
# 82                  rbfn         moco                           3
# 81                  rbfn         moco                           3
# 92                  rbfn         moco                           3
# 93                  rbfn         moco                           3
# 84                  rbfn         moco                           3
# 78                  rbfn         moco                           3
# 77                  rbfn         moco                           3
# 91                  rbfn         moco                           3
# 108                 rbfn         moco                           2
# 24                  rbfn         moco                           2
# 99                  rbfn         moco                           2
# 117                 rbfn         moco                           2
# 115                 rbfn         moco                           2
# 100                 rbfn         moco                           2
# 107                 rbfn         moco                           2
# 113                 rbfn         moco                           2
# 105                 rbfn         moco                           2
# 104                 rbfn         moco                           2
# 75                  rbfn         moco                           3
# 97                  rbfn         moco                           2
# 85                  rbfn         moco                           3
# 67                  rbfn         moco                           4
# 59                  rbfn         moco                           4
# 50                  rbfn         moco                           4
# 58                  rbfn         moco                           4
# 61                  rbfn         moco                           4
# 90                  rbfn         moco                           3
# 89                  rbfn         moco                           3
# 94                  rbfn         moco                           3
# 101                 rbfn         moco                           2
# 109                 rbfn         moco                           2
# 98                  rbfn         moco                           2
# 52                  rbfn         moco                           4
# 49                  rbfn         moco                           4
# 55                  rbfn         moco                           4
# 54                  rbfn         moco                           4
# 87                  rbfn         moco                           3
# 83                  rbfn         moco                           3
# 74                  rbfn         moco                           3
# 86                  rbfn         moco                           3
# 80                  rbfn         moco                           3
# 79                  rbfn         moco                           3
# 72                  rbfn         moco                           4
# 64                  rbfn         moco                           4
# 65                  rbfn         moco                           4
# 66                  rbfn         moco                           4
# 68                  rbfn         moco                           4
# 69                  rbfn         moco                           4
# 70                  rbfn         moco                           4
# 71                  rbfn         moco                           4
# 57                  rbfn         moco                           4
# 62                  rbfn         moco                           4
# 60                  rbfn         moco                           4
# 56                  rbfn         moco                           4
# 63                  rbfn         moco                           4
# 73                  rbfn         moco                           3
# 76                  rbfn         moco                           3
# 88                  rbfn         moco                           3
# 103                 rbfn         moco                           2
# 102                 rbfn         moco                           2
# 96                  rbfn         moco                           3
# 95                  rbfn         moco                           3
# 111                 rbfn         moco                           2
# 110                 rbfn         moco                           2
# 118                 rbfn         moco                           2
# 119                 rbfn         moco                           2
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 116                               512                 inverse_multiquadric
# 51                                128                         multiquadric
# 106                               256                         multiquadric
# 53                                128                 inverse_multiquadric
# 114                               512                         multiquadric
# 112                               512                                  tps
# 82                                256                                  tps
# 81                                256                                  tps
# 92                                512                         multiquadric
# 93                                512                 inverse_multiquadric
# 84                                256                         multiquadric
# 78                                128                 inverse_multiquadric
# 77                                128                 inverse_multiquadric
# 91                                512                         multiquadric
# 108                               256                 inverse_multiquadric
# 24                                128                 inverse_multiquadric
# 99                                128                         multiquadric
# 117                               512                 inverse_multiquadric
# 115                               512                         multiquadric
# 100                               128                         multiquadric
# 107                               256                         multiquadric
# 113                               512                                  tps
# 105                               256                                  tps
# 104                               256                                  tps
# 75                                128                         multiquadric
# 97                                128                                  tps
# 85                                256                 inverse_multiquadric
# 67                                512                         multiquadric
# 59                                256                         multiquadric
# 50                                128                                  tps
# 58                                256                                  tps
# 61                                256                 inverse_multiquadric
# 90                                512                                  tps
# 89                                512                                  tps
# 94                                512                 inverse_multiquadric
# 101                               128                 inverse_multiquadric
# 109                               256                 inverse_multiquadric
# 98                                128                                  tps
# 52                                128                         multiquadric
# 49                                128                                  tps
# 55                                128                             gaussian
# 54                                128                 inverse_multiquadric
# 87                                256                             gaussian
# 83                                256                         multiquadric
# 74                                128                                  tps
# 86                                256                 inverse_multiquadric
# 80                                128                             gaussian
# 79                                128                             gaussian
# 72                                512                             gaussian
# 64                                256                             gaussian
# 65                                512                                  tps
# 66                                512                                  tps
# 68                                512                         multiquadric
# 69                                512                 inverse_multiquadric
# 70                                512                 inverse_multiquadric
# 71                                512                             gaussian
# 57                                256                                  tps
# 62                                256                 inverse_multiquadric
# 60                                256                         multiquadric
# 56                                128                             gaussian
# 63                                256                             gaussian
# 73                                128                                  tps
# 76                                128                         multiquadric
# 88                                256                             gaussian
# 103                               128                             gaussian
# 102                               128                             gaussian
# 96                                512                             gaussian
# 95                                512                             gaussian
# 111                               256                             gaussian
# 110                               256                             gaussian
# 118                               512                             gaussian
# 119                               512                             gaussian
#
#      rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 116                           False                 0.670776
# 51                            False                 0.670766
# 106                           False                 0.670766
# 53                            False                 0.670766
# 114                           False                 0.670766
# 112                           False                 0.670192
# 82                             True                 0.670181
# 81                            False                 0.670181
# 92                             True                 0.670181
# 93                            False                 0.670181
# 84                             True                 0.670181
# 78                             True                 0.670181
# 77                            False                 0.670181
# 91                            False                 0.670181
# 108                           False                 0.670181
# 24                            False                 0.670160
# 99                            False                 0.670160
# 117                            True                 0.670160
# 115                            True                 0.670160
# 100                            True                 0.670160
# 107                            True                 0.670160
# 113                            True                 0.670160
# 105                            True                 0.670160
# 104                           False                 0.669607
# 75                            False                 0.669596
# 97                            False                 0.669596
# 85                            False                 0.669596
# 67                            False                 0.669596
# 59                            False                 0.669596
# 50                             True                 0.669575
# 58                             True                 0.669575
# 61                            False                 0.669575
# 90                             True                 0.669575
# 89                            False                 0.669575
# 94                             True                 0.669575
# 101                            True                 0.669575
# 109                            True                 0.669575
# 98                             True                 0.669575
# 52                             True                 0.668990
# 49                            False                 0.668990
# 55                            False                 0.668990
# 54                             True                 0.668990
# 87                            False                 0.668990
# 83                            False                 0.668990
# 74                             True                 0.668990
# 86                             True                 0.668990
# 80                             True                 0.668990
# 79                            False                 0.668990
# 72                             True                 0.668990
# 64                             True                 0.668990
# 65                            False                 0.668990
# 66                             True                 0.668990
# 68                             True                 0.668990
# 69                            False                 0.668990
# 70                             True                 0.668990
# 71                            False                 0.668990
# 57                            False                 0.668990
# 62                             True                 0.668990
# 60                             True                 0.668990
# 56                             True                 0.668990
# 63                            False                 0.668990
# 73                            False                 0.668990
# 76                             True                 0.668990
# 88                             True                 0.668990
# 103                            True                 0.668990
# 102                           False                 0.668990
# 96                             True                 0.668990
# 95                            False                 0.668990
# 111                            True                 0.668990
# 110                           False                 0.668990
# 118                           False                 0.668990
# 119                            True                 0.668990
#
#      test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 116                0.648089                  0.676999               0.670776
# 51                 0.647860                  0.679236               0.670766
# 106                0.647860                  0.679236               0.670766
# 53                 0.647860                  0.679236               0.670766
# 114                0.647875                  0.679546               0.670766
# 112                0.647398                  0.676612               0.670192
# 82                 0.646831                  0.677937               0.670181
# 81                 0.646831                  0.677937               0.670181
# 92                 0.646831                  0.677937               0.670181
# 93                 0.646831                  0.677937               0.670181
# 84                 0.646831                  0.677937               0.670181
# 78                 0.646785                  0.677852               0.670181
# 77                 0.647355                  0.678310               0.670181
# 91                 0.647355                  0.678310               0.670181
# 108                0.647654                  0.678399               0.670181
# 24                 0.647433                  0.677019               0.670160
# 99                 0.647203                  0.678792               0.670160
# 117                0.647203                  0.678792               0.670160
# 115                0.647203                  0.678792               0.670160
# 100                0.647203                  0.678792               0.670160
# 107                0.647218                  0.679102               0.670160
# 113                0.647157                  0.678707               0.670160
# 105                0.647157                  0.678707               0.670160
# 104                0.646548                  0.675351               0.669607
# 75                 0.646280                  0.676926               0.669596
# 97                 0.646596                  0.675907               0.669596
# 85                 0.646326                  0.677011               0.669596
# 67                 0.646280                  0.676926               0.669596
# 59                 0.646326                  0.677011               0.669596
# 50                 0.646174                  0.677493               0.669575
# 58                 0.646174                  0.677493               0.669575
# 61                 0.646128                  0.677409               0.669575
# 90                 0.646174                  0.677493               0.669575
# 89                 0.646174                  0.677493               0.669575
# 94                 0.646174                  0.677493               0.669575
# 101                0.646174                  0.677493               0.669575
# 109                0.646698                  0.677866               0.669575
# 98                 0.646698                  0.677866               0.669575
# 52                 0.645669                  0.676567               0.668990
# 49                 0.645669                  0.676567               0.668990
# 55                 0.645669                  0.676567               0.668990
# 54                 0.645669                  0.676567               0.668990
# 87                 0.645669                  0.676567               0.668990
# 83                 0.645623                  0.676482               0.668990
# 74                 0.645669                  0.676567               0.668990
# 86                 0.645669                  0.676567               0.668990
# 80                 0.645669                  0.676567               0.668990
# 79                 0.645669                  0.676567               0.668990
# 72                 0.645669                  0.676567               0.668990
# 64                 0.645669                  0.676567               0.668990
# 65                 0.645669                  0.676567               0.668990
# 66                 0.645669                  0.676567               0.668990
# 68                 0.645669                  0.676567               0.668990
# 69                 0.645623                  0.676482               0.668990
# 70                 0.645669                  0.676567               0.668990
# 71                 0.645669                  0.676567               0.668990
# 57                 0.645669                  0.676567               0.668990
# 62                 0.645669                  0.676567               0.668990
# 60                 0.645669                  0.676567               0.668990
# 56                 0.645669                  0.676567               0.668990
# 63                 0.645669                  0.676567               0.668990
# 73                 0.645669                  0.676567               0.668990
# 76                 0.645623                  0.676482               0.668990
# 88                 0.645669                  0.676567               0.668990
# 103                0.645669                  0.676567               0.668990
# 102                0.645669                  0.676567               0.668990
# 96                 0.645669                  0.676567               0.668990
# 95                 0.645669                  0.676567               0.668990
# 111                0.645669                  0.676567               0.668990
# 110                0.645669                  0.676567               0.668990
# 118                0.645669                  0.676567               0.668990
# 119                0.645669                  0.676567               0.668990

# %% [markdown]
# #### BYOL

# %%
df_rbfn_byol = df_rbfn[df_rbfn["architecture"] == "byol"]
df_rbfn_byol = df_rbfn_byol.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_byol
# Out:
#    projection_head_type architecture  projection_head_num_layers  \
# 31                 rbfn         byol                           2
# 32                 rbfn         byol                           2
# 40                 rbfn         byol                           2
# 39                 rbfn         byol                           2
# 47                 rbfn         byol                           2
# 48                 rbfn         byol                           2
# 25                 rbfn         byol                           2
# 26                 rbfn         byol                           2
# 29                 rbfn         byol                           2
# 30                 rbfn         byol                           2
# 27                 rbfn         byol                           2
# 28                 rbfn         byol                           2
# 36                 rbfn         byol                           2
# 35                 rbfn         byol                           2
# 33                 rbfn         byol                           2
# 34                 rbfn         byol                           2
# 37                 rbfn         byol                           2
# 38                 rbfn         byol                           2
# 41                 rbfn         byol                           2
# 42                 rbfn         byol                           2
# 44                 rbfn         byol                           2
# 43                 rbfn         byol                           2
# 46                 rbfn         byol                           2
# 45                 rbfn         byol                           2
#
#     rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 31                               128                             gaussian
# 32                               128                             gaussian
# 40                               256                             gaussian
# 39                               256                             gaussian
# 47                               512                             gaussian
# 48                               512                             gaussian
# 25                               128                                  tps
# 26                               128                                  tps
# 29                               128                 inverse_multiquadric
# 30                               128                 inverse_multiquadric
# 27                               128                         multiquadric
# 28                               128                         multiquadric
# 36                               256                         multiquadric
# 35                               256                         multiquadric
# 33                               256                                  tps
# 34                               256                                  tps
# 37                               256                 inverse_multiquadric
# 38                               256                 inverse_multiquadric
# 41                               512                                  tps
# 42                               512                                  tps
# 44                               512                         multiquadric
# 43                               512                         multiquadric
# 46                               512                 inverse_multiquadric
# 45                               512                 inverse_multiquadric
#
#     rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 31                           False                 0.668949
# 32                            True                 0.668949
# 40                            True                 0.668949
# 39                           False                 0.668949
# 47                           False                 0.668949
# 48                            True                 0.668949
# 25                           False                 0.033333
# 26                            True                 0.033333
# 29                           False                 0.033333
# 30                            True                 0.033333
# 27                           False                 0.033333
# 28                            True                 0.033333
# 36                            True                 0.033333
# 35                           False                 0.033333
# 33                           False                 0.033333
# 34                            True                 0.033333
# 37                           False                 0.033333
# 38                            True                 0.033333
# 41                           False                 0.033333
# 42                            True                 0.033333
# 44                            True                 0.033333
# 43                           False                 0.033333
# 46                            True                 0.033333
# 45                           False                 0.033333
#
#     test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 31                0.646310                  0.680964               0.668949
# 32                0.646310                  0.680964               0.668949
# 40                0.646310                  0.680964               0.668949
# 39                0.646310                  0.680964               0.668949
# 47                0.646310                  0.680964               0.668949
# 48                0.646310                  0.680964               0.668949
# 25                0.002163                  0.001118               0.033333
# 26                0.002163                  0.001118               0.033333
# 29                0.002163                  0.001118               0.033333
# 30                0.002163                  0.001118               0.033333
# 27                0.002163                  0.001118               0.033333
# 28                0.002163                  0.001118               0.033333
# 36                0.002163                  0.001118               0.033333
# 35                0.002163                  0.001118               0.033333
# 33                0.002163                  0.001118               0.033333
# 34                0.002163                  0.001118               0.033333
# 37                0.002163                  0.001118               0.033333
# 38                0.002163                  0.001118               0.033333
# 41                0.002163                  0.001118               0.033333
# 42                0.002163                  0.001118               0.033333
# 44                0.002163                  0.001118               0.033333
# 43                0.002163                  0.001118               0.033333
# 46                0.002163                  0.001118               0.033333
# 45                0.002163                  0.001118               0.033333

# %% [markdown]
# #### SwAV

# %%
df_rbfn_swav = df_rbfn[df_rbfn["architecture"] == "swav"]
df_rbfn_swav = df_rbfn_swav.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_swav
# Out:
#    projection_head_type architecture  projection_head_num_layers  \
# 0                  rbfn         swav                           2
# 8                  rbfn         swav                           2
# 16                 rbfn         swav                           2
# 7                  rbfn         swav                           2
# 15                 rbfn         swav                           2
# 14                 rbfn         swav                           2
# 6                  rbfn         swav                           2
# 23                 rbfn         swav                           2
# 22                 rbfn         swav                           2
# 12                 rbfn         swav                           2
# 1                  rbfn         swav                           2
# 2                  rbfn         swav                           2
# 9                  rbfn         swav                           2
# 10                 rbfn         swav                           2
# 4                  rbfn         swav                           2
# 5                  rbfn         swav                           2
# 17                 rbfn         swav                           2
# 13                 rbfn         swav                           2
# 3                  rbfn         swav                           2
# 11                 rbfn         swav                           2
# 19                 rbfn         swav                           2
# 18                 rbfn         swav                           2
# 21                 rbfn         swav                           2
# 20                 rbfn         swav                           2
#
#     rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 0                                128                                  tps
# 8                                256                                  tps
# 16                               512                                  tps
# 7                                128                             gaussian
# 15                               256                             gaussian
# 14                               256                             gaussian
# 6                                128                             gaussian
# 23                               512                             gaussian
# 22                               512                             gaussian
# 12                               256                 inverse_multiquadric
# 1                                128                                  tps
# 2                                128                         multiquadric
# 9                                256                                  tps
# 10                               256                         multiquadric
# 4                                128                 inverse_multiquadric
# 5                                128                 inverse_multiquadric
# 17                               512                                  tps
# 13                               256                 inverse_multiquadric
# 3                                128                         multiquadric
# 11                               256                         multiquadric
# 19                               512                         multiquadric
# 18                               512                         multiquadric
# 21                               512                 inverse_multiquadric
# 20                               512                 inverse_multiquadric
#
#     rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 0                            False                 0.632073
# 8                            False                 0.611451
# 16                           False                 0.597939
# 7                             True                 0.548603
# 15                            True                 0.548603
# 14                           False                 0.548603
# 6                            False                 0.548603
# 23                            True                 0.548603
# 22                           False                 0.548603
# 12                           False                 0.548603
# 1                             True                 0.534157
# 2                            False                 0.532385
# 9                             True                 0.512420
# 10                           False                 0.413102
# 4                            False                 0.412393
# 5                             True                 0.383924
# 17                            True                 0.357543
# 13                            True                 0.340759
# 3                             True                 0.277110
# 11                            True                 0.182732
# 19                            True                 0.033333
# 18                           False                 0.033333
# 21                            True                 0.033333
# 20                           False                 0.033333
#
#     test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 0                 0.612263                  0.636260               0.632073
# 8                 0.582842                  0.612577               0.611451
# 16                0.568342                  0.606784               0.597939
# 7                 0.511998                  0.572068               0.548603
# 15                0.511998                  0.572068               0.548603
# 14                0.511998                  0.572068               0.548603
# 6                 0.511998                  0.572068               0.548603
# 23                0.511998                  0.572068               0.548603
# 22                0.511998                  0.572068               0.548603
# 12                0.519012                  0.546201               0.548603
# 1                 0.516602                  0.537775               0.534157
# 2                 0.490614                  0.543205               0.532385
# 9                 0.473291                  0.537688               0.512420
# 10                0.353921                  0.382885               0.413102
# 4                 0.344763                  0.382365               0.412393
# 5                 0.309175                  0.434751               0.383924
# 17                0.311091                  0.349769               0.357543
# 13                0.271998                  0.274123               0.340759
# 3                 0.201703                  0.259002               0.277110
# 11                0.110580                  0.140332               0.182732
# 19                0.002163                  0.001118               0.033333
# 18                0.002163                  0.001118               0.033333
# 21                0.002163                  0.001118               0.033333
# 20                0.002163                  0.001118               0.033333

# %% [markdown]
# ## Comparison by Architecture

# %% [markdown]
# ### Top-1 Accuracy

# %%
METRIC_COL = "test_MulticlassAccuracy"

# %% [markdown]
# #### SimCLR

# %%
df_default_rbfn_simclr = pd.concat([df_default_simclr.head(1), df_rbfn_simclr.head(1)])
df_default_rbfn_simclr
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 7                default       simclr                           3
# 144                 rbfn       simclr                           4
#
#      test_MulticlassAccuracy  test_MulticlassF1Score  \
# 7                   0.667250                0.660157
# 144                 0.657795                0.635867
#
#      test_MulticlassPrecision  test_MulticlassRecall  \
# 7                    0.665730               0.667250
# 144                  0.668911               0.657795
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 7                                 NaN                                  NaN
# 144                             128.0                                  tps
#
#     rbfn_projection_head_normalize
# 7                              NaN
# 144                          False

# %%
rbfn_default_diff_simclr = df_default_rbfn_simclr[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_simclr * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): -0.95 %

# %% [markdown]
# #### SimSiam

# %%
df_default_rbfn_simsiam = pd.concat([df_default_simsiam.head(1), df_rbfn_simsiam.head(1)])
df_default_rbfn_simsiam
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 5                default      simsiam                           2
# 122                 rbfn      simsiam                           2
#
#      test_MulticlassAccuracy  test_MulticlassF1Score  \
# 5                   0.689633                0.678074
# 122                 0.669576                0.647635
#
#      test_MulticlassPrecision  test_MulticlassRecall  \
# 5                    0.683768               0.689633
# 122                  0.678805               0.669576
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 5                                 NaN                                  NaN
# 122                             128.0                         multiquadric
#
#     rbfn_projection_head_normalize
# 5                              NaN
# 122                          False

# %%
rbfn_default_diff_simsiam = df_default_rbfn_simsiam[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_simsiam * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): -2.01 %

# %% [markdown]
# #### MoCo

# %%
df_default_rbfn_moco = pd.concat([df_default_moco.head(1), df_rbfn_moco.head(1)])
df_default_rbfn_moco.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_default_rbfn_moco
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 2                default         moco                           4
# 116                 rbfn         moco                           2
#
#      test_MulticlassAccuracy  test_MulticlassF1Score  \
# 2                   0.706176                0.698566
# 116                 0.670776                0.648089
#
#      test_MulticlassPrecision  test_MulticlassRecall  \
# 2                    0.706860               0.706176
# 116                  0.676999               0.670776
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 2                                 NaN                                  NaN
# 116                             512.0                 inverse_multiquadric
#
#     rbfn_projection_head_normalize
# 2                              NaN
# 116                          False

# %%
rbfn_default_diff_moco = df_default_rbfn_moco[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_moco * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): -3.54 %

# %% [markdown]
# #### BYOL

# %%
df_default_rbfn_byol = pd.concat([df_default_byol.head(1), df_rbfn_byol.head(1)])
df_default_rbfn_byol.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_default_rbfn_byol
# Out:
#    projection_head_type architecture  projection_head_num_layers  \
# 31                 rbfn         byol                           2
# 1               default         byol                           2
#
#     test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 31                 0.668949                0.646310                  0.680964
# 1                  0.647984                0.623352                  0.691118
#
#     test_MulticlassRecall  rbfn_projection_head_num_kernels  \
# 31               0.668949                             128.0
# 1                0.647984                               NaN
#
#    rbfn_projection_head_radial_function rbfn_projection_head_normalize
# 31                             gaussian                          False
# 1                                   NaN                            NaN

# %%
rbfn_default_diff_byol = df_default_rbfn_byol[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_byol * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): -2.1 %

# %% [markdown]
# #### SwAV

# %%
df_default_rbfn_swav = pd.concat([df_default_swav.head(1), df_rbfn_swav.head(1)])
df_default_rbfn_swav.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_default_rbfn_swav
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 0              default         swav                           2
# 0                 rbfn         swav                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 0                 0.648224                0.626675                  0.658935
# 0                 0.632073                0.612263                  0.636260
#
#    test_MulticlassRecall  rbfn_projection_head_num_kernels  \
# 0               0.648224                               NaN
# 0               0.632073                             128.0
#
#   rbfn_projection_head_radial_function rbfn_projection_head_normalize
# 0                                  NaN                            NaN
# 0                                  tps                          False

# %%
rbfn_default_diff_swav = df_default_rbfn_swav[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_swav * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): -1.62 %

# %% [markdown]
# #### Peak Performance Across Architectures

# %%
df_default_best = pd.concat([
    df_default_simclr.head(1),
    df_default_simsiam.head(1),
    df_default_moco.head(1),
    df_default_byol.head(1),
    df_default_swav.head(1)  
])
df_default_best.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_default_best
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 2              default         moco                           4
# 5              default      simsiam                           2
# 7              default       simclr                           3
# 0              default         swav                           2
# 1              default         byol                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 2                 0.706176                0.698566                  0.706860
# 5                 0.689633                0.678074                  0.683768
# 7                 0.667250                0.660157                  0.665730
# 0                 0.648224                0.626675                  0.658935
# 1                 0.647984                0.623352                  0.691118
#
#    test_MulticlassRecall
# 2               0.706176
# 5               0.689633
# 7               0.667250
# 0               0.648224
# 1               0.647984

# %%
df_default_best[METRICS].mean()
# Out:
# test_MulticlassAccuracy     0.671853
# test_MulticlassF1Score      0.657365
# test_MulticlassPrecision    0.681282
# test_MulticlassRecall       0.671853
# dtype: float64

# %%
default_best_mean = df_default_best[[METRIC_COL]].mean().iloc[-1]
print(f"Mean {METRIC_COL} (default):", round(default_best_mean * 100, 2), "%")
# Out:
# Mean test_MulticlassAccuracy (default): 67.19 %

# %%
df_rbfn_best = pd.concat([
    df_rbfn_simclr.head(1),
    df_rbfn_simsiam.head(1),
    df_rbfn_moco.head(1),
    df_rbfn_byol.head(1),
    df_rbfn_swav.head(1)
])
df_rbfn_best.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_rbfn_best
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 116                 rbfn         moco                           2
# 122                 rbfn      simsiam                           2
# 31                  rbfn         byol                           2
# 144                 rbfn       simclr                           4
# 0                   rbfn         swav                           2
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 116                               512                 inverse_multiquadric
# 122                               128                         multiquadric
# 31                                128                             gaussian
# 144                               128                                  tps
# 0                                 128                                  tps
#
#      rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 116                           False                 0.670776
# 122                           False                 0.669576
# 31                            False                 0.668949
# 144                           False                 0.657795
# 0                             False                 0.632073
#
#      test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 116                0.648089                  0.676999               0.670776
# 122                0.647635                  0.678805               0.669576
# 31                 0.646310                  0.680964               0.668949
# 144                0.635867                  0.668911               0.657795
# 0                  0.612263                  0.636260               0.632073

# %%
df_rbfn_best[METRICS].mean()
# Out:
# test_MulticlassAccuracy     0.659834
# test_MulticlassF1Score      0.638033
# test_MulticlassPrecision    0.668388
# test_MulticlassRecall       0.659834
# dtype: float64

# %%
rbfn_best_mean = df_rbfn_best[[METRIC_COL]].mean().iloc[-1]
print(f"Mean {METRIC_COL} (RBFN):", round(rbfn_best_mean * 100, 2), "%")
# Out:
# Mean test_MulticlassAccuracy (RBFN): 65.98 %

# %%
print(f"Diff. mean {METRIC_COL} RBFN <-> default:", round((rbfn_best_mean - default_best_mean) * 100, 2), "%")
# Out:
# Diff. mean test_MulticlassAccuracy RBFN <-> default: -1.2 %

# %%
#### Average Performance Across Architectures

# %%
df_default_average = pd.concat([
    df_default_moco[METRICS].mean().to_frame().T.assign(architecture="moco", projection_head_type="default"),
    df_default_simclr[METRICS].mean().to_frame().T.assign(architecture="simclr", projection_head_type="default"),
    df_default_byol[METRICS].mean().to_frame().T.assign(architecture="byol", projection_head_type="default"),
    df_default_swav[METRICS].mean().to_frame().T.assign(architecture="swav", projection_head_type="default"),
    df_default_simsiam[METRICS].mean().to_frame().T.assign(architecture="simsiam", projection_head_type="default"),
], ignore_index=True)

df_default_average
# Out:
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 0                 0.703987                0.696459                  0.704938
# 1                 0.659828                0.652935                  0.660606
# 2                 0.647984                0.623352                  0.691118
# 3                 0.648224                0.626675                  0.658935
# 4                 0.689633                0.678074                  0.683768
#
#    test_MulticlassRecall architecture projection_head_type
# 0               0.703987         moco              default
# 1               0.659828       simclr              default
# 2               0.647984         byol              default
# 3               0.648224         swav              default
# 4               0.689633      simsiam              default

# %%
df_default_average[METRICS].mean()
# Out:
# test_MulticlassAccuracy     0.669931
# test_MulticlassF1Score      0.655499
# test_MulticlassPrecision    0.679873
# test_MulticlassRecall       0.669931
# dtype: float64

# %%
df_rbfn_average = pd.concat([
    df_rbfn_moco[METRICS].mean().to_frame().T.assign(architecture="moco", projection_head_type="rbfn"),
    df_rbfn_simclr[METRICS].mean().to_frame().T.assign(architecture="simclr", projection_head_type="rbfn"),
    df_rbfn_byol[METRICS].mean().to_frame().T.assign(architecture="byol", projection_head_type="rbfn"),
    df_rbfn_swav[METRICS].mean().to_frame().T.assign(architecture="swav", projection_head_type="rbfn"),
    df_rbfn_simsiam[METRICS].mean().to_frame().T.assign(architecture="simsiam", projection_head_type="rbfn"),
], ignore_index=True)

df_rbfn_average
# Out:
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 0                 0.669533                0.646327                  0.677255
# 1                 0.414131                0.385765                  0.411129
# 2                 0.192237                0.163200                  0.171079
# 3                 0.406731                0.364452                  0.403358
# 4                 0.668308                0.645827                  0.678375
#
#    test_MulticlassRecall architecture projection_head_type
# 0               0.669533         moco                 rbfn
# 1               0.414131       simclr                 rbfn
# 2               0.192237         byol                 rbfn
# 3               0.406731         swav                 rbfn
# 4               0.668308      simsiam                 rbfn

# %%
df_rbfn_average[METRICS].mean()
# Out:
# test_MulticlassAccuracy     0.470188
# test_MulticlassF1Score      0.441114
# test_MulticlassPrecision    0.468239
# test_MulticlassRecall       0.470188
# dtype: float64

# %% [markdown]
# ### SHAP Analysis of RBFN Parameters

# %%
X = df_rbfn.drop(columns=[
    MAIN_METRIC,
    "test_MulticlassF1Score",
    "test_MulticlassPrecision",
    "test_MulticlassRecall",
    "projection_head_type",
    "architecture"])
y = df_rbfn[MAIN_METRIC]

# %%
X = pd.get_dummies(X, drop_first=False)
bool_cols = X.select_dtypes(include=["bool"]).columns
X[bool_cols] = X[bool_cols].astype(int)

# %%
xgb_model = XGBRegressor()
xgb_model.fit(X, y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
explainer = shap.Explainer(xgb_model, X)
shap_values = explainer(X)

# %%
shap_df = pd.DataFrame(shap_values.values, columns=X.columns)
importance_table = pd.DataFrame({
    "mean_abs_shap": shap_df.abs().mean(),
    "positive_mean": shap_df.where(shap_df > 0).mean(),
    "negative_mean": shap_df.where(shap_df < 0).mean(),
    "std": shap_df.std()
})
importance_table = importance_table.sort_values("mean_abs_shap", ascending=False)
importance_table.round(2)
# Out:
#                                                     mean_abs_shap  \
# rbfn_projection_head_radial_function_gaussian                0.08
# projection_head_num_layers                                   0.02
# rbfn_projection_head_normalize                               0.02
# rbfn_projection_head_radial_function_tps                     0.02
# rbfn_projection_head_num_kernels                             0.02
# rbfn_projection_head_radial_function_inverse_mu...           0.00
# rbfn_projection_head_radial_function_multiquadric            0.00
#
#                                                     positive_mean  \
# rbfn_projection_head_radial_function_gaussian                0.16
# projection_head_num_layers                                   0.03
# rbfn_projection_head_normalize                               0.02
# rbfn_projection_head_radial_function_tps                     0.05
# rbfn_projection_head_num_kernels                             0.01
# rbfn_projection_head_radial_function_inverse_mu...           0.00
# rbfn_projection_head_radial_function_multiquadric            0.00
#
#                                                     negative_mean   std
# rbfn_projection_head_radial_function_gaussian               -0.05  0.09
# projection_head_num_layers                                  -0.02  0.04
# rbfn_projection_head_normalize                              -0.02  0.03
# rbfn_projection_head_radial_function_tps                    -0.01  0.03
# rbfn_projection_head_num_kernels                            -0.03  0.02
# rbfn_projection_head_radial_function_inverse_mu...          -0.01  0.01
# rbfn_projection_head_radial_function_multiquadric           -0.00  0.00

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)
