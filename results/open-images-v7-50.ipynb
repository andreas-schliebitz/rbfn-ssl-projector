# %% [markdown]
# # OpenImagesV7-50

# %%
import shap
import pandas as pd
import numpy as np

from pathlib import Path
from xgboost import XGBRegressor

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
DATASET_NAME = "open-images-v7-50"
METRICS = ["test_MulticlassAccuracy", "test_MulticlassF1Score", "test_MulticlassPrecision", "test_MulticlassRecall"]
MAIN_METRIC = "test_MulticlassAccuracy"

# %%
RESULTS_PATH = Path(".").resolve()

# %% [markdown]
# ## Default Projector

# %%
DEFAULT_EVAL_RESULTS_PATH = RESULTS_PATH.joinpath(DATASET_NAME, "default", f"rbfn-ssl-projector-default-eval_{DATASET_NAME}.csv")
print(DEFAULT_EVAL_RESULTS_PATH)
DEFAULT_RANGES = [
    "architecture",
    "projection_head_num_layers"
]
# Out:
# /cluster/user/aschlieb/promotion/code/rbfn-ssl-projector/results/open-images-v7-50/default/rbfn-ssl-projector-default-eval_open-images-v7-50.csv

# %%
df_default = pd.read_csv(DEFAULT_EVAL_RESULTS_PATH)
df_default = df_default[["projection_head_type"] + DEFAULT_RANGES + METRICS]

# %% [markdown]
# ### By Architecture

# %% [markdown]
# #### SimCLR

# %%
df_default_simclr = df_default[df_default["architecture"] == "simclr"]
df_default_simclr = df_default_simclr.sort_values(by=MAIN_METRIC, ascending=False)
df_default_simclr
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 8              default       simclr                           2
# 6              default       simclr                           4
# 7              default       simclr                           3
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 8                 0.542997                0.521593                  0.535298
# 6                 0.541025                0.517430                  0.532497
# 7                 0.530010                0.513196                  0.531541
#
#    test_MulticlassRecall
# 8               0.542997
# 6               0.541025
# 7               0.530010

# %% [markdown]
# #### SimSiam

# %%
df_default_simsiam = df_default[df_default["architecture"] == "simsiam"]
df_default_simsiam = df_default_simsiam.sort_values(by=MAIN_METRIC, ascending=False)
df_default_simsiam
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 5              default      simsiam                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 5                 0.573259                0.546128                  0.562275
#
#    test_MulticlassRecall
# 5               0.573259

# %% [markdown]
# #### MoCo

# %%
df_default_moco = df_default[df_default["architecture"] == "moco"]
df_default_moco = df_default_moco.sort_values(by=MAIN_METRIC, ascending=False)
df_default_moco
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 3              default         moco                           3
# 2              default         moco                           4
# 4              default         moco                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 3                 0.577996                0.554181                  0.560400
# 2                 0.577350                0.553881                  0.563015
# 4                 0.575952                0.553539                  0.560879
#
#    test_MulticlassRecall
# 3               0.577996
# 2               0.577350
# 4               0.575952

# %% [markdown]
# #### BYOL

# %%
df_default_byol = df_default[df_default["architecture"] == "byol"]
df_default_byol = df_default_byol.sort_values(by=MAIN_METRIC, ascending=False)
df_default_byol
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 1              default         byol                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 1                 0.523573                0.491362                  0.552817
#
#    test_MulticlassRecall
# 1               0.523573

# %% [markdown]
# #### SwAV

# %%
df_default_swav = df_default[df_default["architecture"] == "swav"]
df_default_swav = df_default_swav.sort_values(by=MAIN_METRIC, ascending=False)
df_default_swav
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 0              default         swav                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 0                 0.513985                0.472366                  0.475897
#
#    test_MulticlassRecall
# 0               0.513985

# %% [markdown]
# ## RBFN Projector

# %%
RBFN_EVAL_RESULTS_PATH = RESULTS_PATH.joinpath(DATASET_NAME, "rbfn", f"rbfn-ssl-projector-rbfn-eval_{DATASET_NAME}.csv")
print(RBFN_EVAL_RESULTS_PATH)

RBFN_RANGES = [
    "architecture",
    "projection_head_num_layers",
    "rbfn_projection_head_num_kernels",
    "rbfn_projection_head_radial_function",
    "rbfn_projection_head_normalize"
]
# Out:
# /cluster/user/aschlieb/promotion/code/rbfn-ssl-projector/results/open-images-v7-50/rbfn/rbfn-ssl-projector-rbfn-eval_open-images-v7-50.csv

# %% [markdown]
# ### By Architecture

# %%
df_rbfn = pd.read_csv(RBFN_EVAL_RESULTS_PATH)
df_rbfn = df_rbfn[["projection_head_type"] + RBFN_RANGES + METRICS]

# %% [markdown]
# #### SimCLR

# %%
df_rbfn_simclr = df_rbfn[df_rbfn["architecture"] == "simclr"]
df_rbfn_simclr = df_rbfn_simclr.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_simclr
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 144                 rbfn       simclr                           4
# 151                 rbfn       simclr                           4
# 150                 rbfn       simclr                           4
# 167                 rbfn       simclr                           4
# 160                 rbfn       simclr                           4
# 158                 rbfn       simclr                           4
# 159                 rbfn       simclr                           4
# 152                 rbfn       simclr                           4
# 206                 rbfn       simclr                           2
# 207                 rbfn       simclr                           2
# 215                 rbfn       simclr                           2
# 214                 rbfn       simclr                           2
# 198                 rbfn       simclr                           2
# 166                 rbfn       simclr                           4
# 175                 rbfn       simclr                           3
# 174                 rbfn       simclr                           3
# 182                 rbfn       simclr                           3
# 183                 rbfn       simclr                           3
# 191                 rbfn       simclr                           3
# 190                 rbfn       simclr                           3
# 199                 rbfn       simclr                           2
# 192                 rbfn       simclr                           2
# 208                 rbfn       simclr                           2
# 200                 rbfn       simclr                           2
# 194                 rbfn       simclr                           2
# 202                 rbfn       simclr                           2
# 193                 rbfn       simclr                           2
# 210                 rbfn       simclr                           2
# 163                 rbfn       simclr                           4
# 201                 rbfn       simclr                           2
# 196                 rbfn       simclr                           2
# 165                 rbfn       simclr                           4
# 155                 rbfn       simclr                           4
# 204                 rbfn       simclr                           2
# 195                 rbfn       simclr                           2
# 209                 rbfn       simclr                           2
# 212                 rbfn       simclr                           2
# 203                 rbfn       simclr                           2
# 157                 rbfn       simclr                           4
# 205                 rbfn       simclr                           2
# 197                 rbfn       simclr                           2
# 147                 rbfn       simclr                           4
# 161                 rbfn       simclr                           4
# 168                 rbfn       simclr                           3
# 149                 rbfn       simclr                           4
# 184                 rbfn       simclr                           3
# 178                 rbfn       simclr                           3
# 176                 rbfn       simclr                           3
# 170                 rbfn       simclr                           3
# 153                 rbfn       simclr                           4
# 145                 rbfn       simclr                           4
# 186                 rbfn       simclr                           3
# 189                 rbfn       simclr                           3
# 179                 rbfn       simclr                           3
# 181                 rbfn       simclr                           3
# 146                 rbfn       simclr                           4
# 148                 rbfn       simclr                           4
# 154                 rbfn       simclr                           4
# 156                 rbfn       simclr                           4
# 177                 rbfn       simclr                           3
# 172                 rbfn       simclr                           3
# 169                 rbfn       simclr                           3
# 162                 rbfn       simclr                           4
# 164                 rbfn       simclr                           4
# 211                 rbfn       simclr                           2
# 188                 rbfn       simclr                           3
# 180                 rbfn       simclr                           3
# 185                 rbfn       simclr                           3
# 213                 rbfn       simclr                           2
# 173                 rbfn       simclr                           3
# 171                 rbfn       simclr                           3
# 187                 rbfn       simclr                           3
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 144                               128                                  tps
# 151                               128                             gaussian
# 150                               128                             gaussian
# 167                               512                             gaussian
# 160                               512                                  tps
# 158                               256                             gaussian
# 159                               256                             gaussian
# 152                               256                                  tps
# 206                               256                             gaussian
# 207                               256                             gaussian
# 215                               512                             gaussian
# 214                               512                             gaussian
# 198                               128                             gaussian
# 166                               512                             gaussian
# 175                               128                             gaussian
# 174                               128                             gaussian
# 182                               256                             gaussian
# 183                               256                             gaussian
# 191                               512                             gaussian
# 190                               512                             gaussian
# 199                               128                             gaussian
# 192                               128                                  tps
# 208                               512                                  tps
# 200                               256                                  tps
# 194                               128                         multiquadric
# 202                               256                         multiquadric
# 193                               128                                  tps
# 210                               512                         multiquadric
# 163                               512                         multiquadric
# 201                               256                                  tps
# 196                               128                 inverse_multiquadric
# 165                               512                 inverse_multiquadric
# 155                               256                         multiquadric
# 204                               256                 inverse_multiquadric
# 195                               128                         multiquadric
# 209                               512                                  tps
# 212                               512                 inverse_multiquadric
# 203                               256                         multiquadric
# 157                               256                 inverse_multiquadric
# 205                               256                 inverse_multiquadric
# 197                               128                 inverse_multiquadric
# 147                               128                         multiquadric
# 161                               512                                  tps
# 168                               128                                  tps
# 149                               128                 inverse_multiquadric
# 184                               512                                  tps
# 178                               256                         multiquadric
# 176                               256                                  tps
# 170                               128                         multiquadric
# 153                               256                                  tps
# 145                               128                                  tps
# 186                               512                         multiquadric
# 189                               512                 inverse_multiquadric
# 179                               256                         multiquadric
# 181                               256                 inverse_multiquadric
# 146                               128                         multiquadric
# 148                               128                 inverse_multiquadric
# 154                               256                         multiquadric
# 156                               256                 inverse_multiquadric
# 177                               256                                  tps
# 172                               128                 inverse_multiquadric
# 169                               128                                  tps
# 162                               512                         multiquadric
# 164                               512                 inverse_multiquadric
# 211                               512                         multiquadric
# 188                               512                 inverse_multiquadric
# 180                               256                 inverse_multiquadric
# 185                               512                                  tps
# 213                               512                 inverse_multiquadric
# 173                               128                 inverse_multiquadric
# 171                               128                         multiquadric
# 187                               512                         multiquadric
#
#      rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 144                           False                 0.542519
# 151                            True                 0.542519
# 150                           False                 0.542519
# 167                            True                 0.542519
# 160                           False                 0.542519
# 158                           False                 0.542519
# 159                            True                 0.542519
# 152                           False                 0.542519
# 206                           False                 0.542519
# 207                            True                 0.542519
# 215                            True                 0.542519
# 214                           False                 0.542519
# 198                           False                 0.542519
# 166                           False                 0.542519
# 175                            True                 0.542519
# 174                           False                 0.542519
# 182                           False                 0.542519
# 183                            True                 0.542519
# 191                            True                 0.542519
# 190                           False                 0.542519
# 199                            True                 0.542519
# 192                           False                 0.523476
# 208                           False                 0.488002
# 200                           False                 0.484364
# 194                           False                 0.472132
# 202                           False                 0.438273
# 193                            True                 0.429720
# 210                           False                 0.424369
# 163                            True                 0.413179
# 201                            True                 0.412467
# 196                           False                 0.403957
# 165                            True                 0.403706
# 155                            True                 0.376766
# 204                           False                 0.372012
# 195                            True                 0.371579
# 209                            True                 0.367176
# 212                           False                 0.361999
# 203                            True                 0.358319
# 157                            True                 0.353235
# 205                            True                 0.344374
# 197                            True                 0.343307
# 147                            True                 0.339127
# 161                            True                 0.285419
# 168                           False                 0.242283
# 149                            True                 0.231119
# 184                           False                 0.211486
# 178                           False                 0.209316
# 176                           False                 0.193204
# 170                           False                 0.191936
# 153                            True                 0.169945
# 145                            True                 0.094960
# 186                           False                 0.091838
# 189                            True                 0.022000
# 179                            True                 0.021381
# 181                            True                 0.020026
# 146                           False                 0.020000
# 148                           False                 0.020000
# 154                           False                 0.020000
# 156                           False                 0.020000
# 177                            True                 0.020000
# 172                           False                 0.020000
# 169                            True                 0.020000
# 162                           False                 0.020000
# 164                           False                 0.020000
# 211                            True                 0.020000
# 188                           False                 0.020000
# 180                           False                 0.020000
# 185                            True                 0.020000
# 213                            True                 0.020000
# 173                            True                 0.019619
# 171                            True                 0.018975
# 187                            True                 0.018667
#
#      test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 144                0.513374                  0.540129               0.542519
# 151                0.513374                  0.540129               0.542519
# 150                0.513374                  0.540129               0.542519
# 167                0.513374                  0.540129               0.542519
# 160                0.513374                  0.540129               0.542519
# 158                0.513374                  0.540129               0.542519
# 159                0.513374                  0.540129               0.542519
# 152                0.513374                  0.540129               0.542519
# 206                0.513374                  0.540129               0.542519
# 207                0.513374                  0.540129               0.542519
# 215                0.513374                  0.540129               0.542519
# 214                0.513374                  0.540129               0.542519
# 198                0.513374                  0.540129               0.542519
# 166                0.513374                  0.540129               0.542519
# 175                0.513374                  0.540129               0.542519
# 174                0.513374                  0.540129               0.542519
# 182                0.513374                  0.540129               0.542519
# 183                0.513374                  0.540129               0.542519
# 191                0.513374                  0.540129               0.542519
# 190                0.513374                  0.540129               0.542519
# 199                0.513374                  0.540129               0.542519
# 192                0.500212                  0.503339               0.523476
# 208                0.453867                  0.470180               0.488002
# 200                0.461487                  0.471617               0.484364
# 194                0.435518                  0.435910               0.472132
# 202                0.397935                  0.415978               0.438273
# 193                0.403093                  0.418580               0.429720
# 210                0.372884                  0.385605               0.424369
# 163                0.391550                  0.466756               0.413179
# 201                0.371570                  0.380626               0.412467
# 196                0.352825                  0.383984               0.403957
# 165                0.378711                  0.438811               0.403706
# 155                0.351629                  0.397253               0.376766
# 204                0.315181                  0.318176               0.372012
# 195                0.326534                  0.331960               0.371579
# 209                0.330285                  0.344950               0.367176
# 212                0.286979                  0.321016               0.361999
# 203                0.313935                  0.325343               0.358319
# 157                0.330301                  0.372328               0.353235
# 205                0.285734                  0.297501               0.344374
# 197                0.291093                  0.300945               0.343307
# 147                0.315539                  0.358942               0.339127
# 161                0.261839                  0.306310               0.285419
# 168                0.183697                  0.210151               0.242283
# 149                0.205570                  0.256254               0.231119
# 184                0.142860                  0.160216               0.211486
# 178                0.159391                  0.168352               0.209316
# 176                0.132295                  0.178566               0.193204
# 170                0.138406                  0.139683               0.191936
# 153                0.148640                  0.204012               0.169945
# 145                0.076343                  0.124885               0.094960
# 186                0.050448                  0.069721               0.091838
# 189                0.003225                  0.001907               0.022000
# 179                0.004362                  0.002908               0.021381
# 181                0.004236                  0.002653               0.020026
# 146                0.000786                  0.000401               0.020000
# 148                0.000786                  0.000401               0.020000
# 154                0.000786                  0.000401               0.020000
# 156                0.000786                  0.000401               0.020000
# 177                0.000786                  0.000401               0.020000
# 172                0.000786                  0.000401               0.020000
# 169                0.000787                  0.000402               0.020000
# 162                0.000786                  0.000401               0.020000
# 164                0.000786                  0.000401               0.020000
# 211                0.000786                  0.000401               0.020000
# 188                0.000786                  0.000401               0.020000
# 180                0.000786                  0.000401               0.020000
# 185                0.000786                  0.000401               0.020000
# 213                0.000786                  0.000401               0.020000
# 173                0.006198                  0.022901               0.019619
# 171                0.006335                  0.005028               0.018975
# 187                0.001955                  0.001208               0.018667

# %% [markdown]
# #### SimSiam

# %%
df_rbfn_simsiam = df_rbfn[df_rbfn["architecture"] == "simsiam"]
df_rbfn_simsiam = df_rbfn_simsiam.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_simsiam
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 121                 rbfn      simsiam                           2
# 123                 rbfn      simsiam                           2
# 126                 rbfn      simsiam                           2
# 124                 rbfn      simsiam                           2
# 127                 rbfn      simsiam                           2
# 133                 rbfn      simsiam                           2
# 134                 rbfn      simsiam                           2
# 129                 rbfn      simsiam                           2
# 140                 rbfn      simsiam                           2
# 141                 rbfn      simsiam                           2
# 142                 rbfn      simsiam                           2
# 132                 rbfn      simsiam                           2
# 135                 rbfn      simsiam                           2
# 143                 rbfn      simsiam                           2
# 125                 rbfn      simsiam                           2
# 139                 rbfn      simsiam                           2
# 131                 rbfn      simsiam                           2
# 137                 rbfn      simsiam                           2
# 130                 rbfn      simsiam                           2
# 122                 rbfn      simsiam                           2
# 138                 rbfn      simsiam                           2
# 136                 rbfn      simsiam                           2
# 128                 rbfn      simsiam                           2
# 120                 rbfn      simsiam                           2
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 121                               128                                  tps
# 123                               128                         multiquadric
# 126                               128                             gaussian
# 124                               128                 inverse_multiquadric
# 127                               128                             gaussian
# 133                               256                 inverse_multiquadric
# 134                               256                             gaussian
# 129                               256                                  tps
# 140                               512                 inverse_multiquadric
# 141                               512                 inverse_multiquadric
# 142                               512                             gaussian
# 132                               256                 inverse_multiquadric
# 135                               256                             gaussian
# 143                               512                             gaussian
# 125                               128                 inverse_multiquadric
# 139                               512                         multiquadric
# 131                               256                         multiquadric
# 137                               512                                  tps
# 130                               256                         multiquadric
# 122                               128                         multiquadric
# 138                               512                         multiquadric
# 136                               512                                  tps
# 128                               256                                  tps
# 120                               128                                  tps
#
#      rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 121                            True                 0.551033
# 123                            True                 0.551033
# 126                           False                 0.551033
# 124                           False                 0.551033
# 127                            True                 0.551033
# 133                            True                 0.551033
# 134                           False                 0.551033
# 129                            True                 0.551033
# 140                           False                 0.551033
# 141                            True                 0.551033
# 142                           False                 0.551033
# 132                           False                 0.551033
# 135                            True                 0.551033
# 143                            True                 0.551033
# 125                            True                 0.550367
# 139                            True                 0.550367
# 131                            True                 0.550367
# 137                            True                 0.550367
# 130                           False                 0.546407
# 122                           False                 0.545740
# 138                           False                 0.545050
# 136                           False                 0.540493
# 128                           False                 0.539136
# 120                           False                 0.539135
#
#      test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 121                0.522133                  0.552446               0.551033
# 123                0.522133                  0.552446               0.551033
# 126                0.522133                  0.552446               0.551033
# 124                0.522105                  0.552645               0.551033
# 127                0.522133                  0.552446               0.551033
# 133                0.522133                  0.552446               0.551033
# 134                0.522133                  0.552446               0.551033
# 129                0.522133                  0.552446               0.551033
# 140                0.521405                  0.551226               0.551033
# 141                0.522133                  0.552446               0.551033
# 142                0.522133                  0.552446               0.551033
# 132                0.522007                  0.552487               0.551033
# 135                0.522133                  0.552446               0.551033
# 143                0.522133                  0.552446               0.551033
# 125                0.521443                  0.552025               0.550367
# 139                0.521443                  0.552025               0.550367
# 131                0.521443                  0.552025               0.550367
# 137                0.521443                  0.552025               0.550367
# 130                0.519579                  0.552852               0.546407
# 122                0.519097                  0.552534               0.545740
# 138                0.518480                  0.552648               0.545050
# 136                0.515819                  0.550637               0.540493
# 128                0.514202                  0.548921               0.539136
# 120                0.514068                  0.548225               0.539135

# %% [markdown]
# #### MoCo

# %%
df_rbfn_moco = df_rbfn[df_rbfn["architecture"] == "moco"]
df_rbfn_moco = df_rbfn_moco.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_moco
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 104                 rbfn         moco                           2
# 112                 rbfn         moco                           2
# 98                  rbfn         moco                           2
# 106                 rbfn         moco                           2
# 96                  rbfn         moco                           2
# 108                 rbfn         moco                           2
# 114                 rbfn         moco                           2
# 51                  rbfn         moco                           4
# 107                 rbfn         moco                           2
# 117                 rbfn         moco                           2
# 113                 rbfn         moco                           2
# 115                 rbfn         moco                           2
# 105                 rbfn         moco                           2
# 109                 rbfn         moco                           2
# 53                  rbfn         moco                           4
# 58                  rbfn         moco                           4
# 80                  rbfn         moco                           3
# 60                  rbfn         moco                           4
# 68                  rbfn         moco                           4
# 66                  rbfn         moco                           4
# 76                  rbfn         moco                           3
# 83                  rbfn         moco                           3
# 85                  rbfn         moco                           3
# 84                  rbfn         moco                           3
# 92                  rbfn         moco                           3
# 90                  rbfn         moco                           3
# 97                  rbfn         moco                           2
# 93                  rbfn         moco                           3
# 89                  rbfn         moco                           3
# 75                  rbfn         moco                           3
# 99                  rbfn         moco                           2
# 101                 rbfn         moco                           2
# 88                  rbfn         moco                           3
# 81                  rbfn         moco                           3
# 82                  rbfn         moco                           3
# 77                  rbfn         moco                           3
# 74                  rbfn         moco                           3
# 116                 rbfn         moco                           2
# 73                  rbfn         moco                           3
# 49                  rbfn         moco                           4
# 55                  rbfn         moco                           4
# 54                  rbfn         moco                           4
# 52                  rbfn         moco                           4
# 50                  rbfn         moco                           4
# 8                   rbfn         moco                           4
# 87                  rbfn         moco                           3
# 57                  rbfn         moco                           4
# 56                  rbfn         moco                           4
# 63                  rbfn         moco                           4
# 62                  rbfn         moco                           4
# 65                  rbfn         moco                           4
# 64                  rbfn         moco                           4
# 67                  rbfn         moco                           4
# 69                  rbfn         moco                           4
# 70                  rbfn         moco                           4
# 71                  rbfn         moco                           4
# 59                  rbfn         moco                           4
# 86                  rbfn         moco                           3
# 78                  rbfn         moco                           3
# 79                  rbfn         moco                           3
# 72                  rbfn         moco                           3
# 61                  rbfn         moco                           4
# 94                  rbfn         moco                           3
# 91                  rbfn         moco                           3
# 103                 rbfn         moco                           2
# 102                 rbfn         moco                           2
# 100                 rbfn         moco                           2
# 95                  rbfn         moco                           3
# 111                 rbfn         moco                           2
# 110                 rbfn         moco                           2
# 118                 rbfn         moco                           2
# 119                 rbfn         moco                           2
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 104                               256                                  tps
# 112                               512                                  tps
# 98                                128                         multiquadric
# 106                               256                         multiquadric
# 96                                128                                  tps
# 108                               256                 inverse_multiquadric
# 114                               512                         multiquadric
# 51                                128                         multiquadric
# 107                               256                         multiquadric
# 117                               512                 inverse_multiquadric
# 113                               512                                  tps
# 115                               512                         multiquadric
# 105                               256                                  tps
# 109                               256                 inverse_multiquadric
# 53                                128                 inverse_multiquadric
# 58                                256                         multiquadric
# 80                                256                                  tps
# 60                                256                 inverse_multiquadric
# 68                                512                 inverse_multiquadric
# 66                                512                         multiquadric
# 76                                128                 inverse_multiquadric
# 83                                256                         multiquadric
# 85                                256                 inverse_multiquadric
# 84                                256                 inverse_multiquadric
# 92                                512                 inverse_multiquadric
# 90                                512                         multiquadric
# 97                                128                                  tps
# 93                                512                 inverse_multiquadric
# 89                                512                                  tps
# 75                                128                         multiquadric
# 99                                128                         multiquadric
# 101                               128                 inverse_multiquadric
# 88                                512                                  tps
# 81                                256                                  tps
# 82                                256                         multiquadric
# 77                                128                 inverse_multiquadric
# 74                                128                         multiquadric
# 116                               512                 inverse_multiquadric
# 73                                128                                  tps
# 49                                128                                  tps
# 55                                128                             gaussian
# 54                                128                 inverse_multiquadric
# 52                                128                         multiquadric
# 50                                128                                  tps
# 8                                 128                             gaussian
# 87                                256                             gaussian
# 57                                256                                  tps
# 56                                256                                  tps
# 63                                256                             gaussian
# 62                                256                             gaussian
# 65                                512                                  tps
# 64                                512                                  tps
# 67                                512                         multiquadric
# 69                                512                 inverse_multiquadric
# 70                                512                             gaussian
# 71                                512                             gaussian
# 59                                256                         multiquadric
# 86                                256                             gaussian
# 78                                128                             gaussian
# 79                                128                             gaussian
# 72                                128                                  tps
# 61                                256                 inverse_multiquadric
# 94                                512                             gaussian
# 91                                512                         multiquadric
# 103                               128                             gaussian
# 102                               128                             gaussian
# 100                               128                 inverse_multiquadric
# 95                                512                             gaussian
# 111                               256                             gaussian
# 110                               256                             gaussian
# 118                               512                             gaussian
# 119                               512                             gaussian
#
#      rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 104                           False                 0.555013
# 112                           False                 0.554368
# 98                            False                 0.553701
# 106                           False                 0.553701
# 96                            False                 0.553679
# 108                           False                 0.553657
# 114                           False                 0.553657
# 51                            False                 0.553012
# 107                            True                 0.553012
# 117                            True                 0.553012
# 113                            True                 0.553012
# 115                            True                 0.553012
# 105                            True                 0.553012
# 109                            True                 0.553012
# 53                            False                 0.553012
# 58                            False                 0.553012
# 80                            False                 0.553012
# 60                            False                 0.553012
# 68                            False                 0.553012
# 66                            False                 0.553012
# 76                            False                 0.553012
# 83                             True                 0.553012
# 85                             True                 0.553012
# 84                            False                 0.553012
# 92                            False                 0.553012
# 90                            False                 0.553012
# 97                             True                 0.553012
# 93                             True                 0.553012
# 89                             True                 0.553012
# 75                             True                 0.553012
# 99                             True                 0.553012
# 101                            True                 0.553012
# 88                            False                 0.553012
# 81                             True                 0.553012
# 82                            False                 0.553012
# 77                             True                 0.553012
# 74                            False                 0.553012
# 116                           False                 0.553012
# 73                             True                 0.553012
# 49                            False                 0.552345
# 55                             True                 0.552345
# 54                             True                 0.552345
# 52                             True                 0.552345
# 50                             True                 0.552345
# 8                             False                 0.552345
# 87                             True                 0.552345
# 57                             True                 0.552345
# 56                            False                 0.552345
# 63                             True                 0.552345
# 62                            False                 0.552345
# 65                             True                 0.552345
# 64                            False                 0.552345
# 67                             True                 0.552345
# 69                             True                 0.552345
# 70                            False                 0.552345
# 71                             True                 0.552345
# 59                             True                 0.552345
# 86                            False                 0.552345
# 78                            False                 0.552345
# 79                             True                 0.552345
# 72                            False                 0.552345
# 61                             True                 0.552345
# 94                            False                 0.552345
# 91                             True                 0.552345
# 103                            True                 0.552345
# 102                           False                 0.552345
# 100                           False                 0.552345
# 95                             True                 0.552345
# 111                            True                 0.552345
# 110                           False                 0.552345
# 118                           False                 0.552345
# 119                            True                 0.552345
#
#      test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 104                0.525515                  0.550786               0.555013
# 112                0.524856                  0.550360               0.554368
# 98                 0.523799                  0.548855               0.553701
# 106                0.523799                  0.548855               0.553701
# 96                 0.524358                  0.549892               0.553679
# 108                0.523933                  0.549905               0.553657
# 114                0.523547                  0.548793               0.553657
# 51                 0.522907                  0.548394               0.553012
# 107                0.522907                  0.548394               0.553012
# 117                0.522907                  0.548394               0.553012
# 113                0.522907                  0.548394               0.553012
# 115                0.522907                  0.548394               0.553012
# 105                0.522907                  0.548394               0.553012
# 109                0.522907                  0.548394               0.553012
# 53                 0.522907                  0.548394               0.553012
# 58                 0.522907                  0.548394               0.553012
# 80                 0.522907                  0.548394               0.553012
# 60                 0.522907                  0.548394               0.553012
# 68                 0.522907                  0.548394               0.553012
# 66                 0.522907                  0.548394               0.553012
# 76                 0.522907                  0.548394               0.553012
# 83                 0.522907                  0.548394               0.553012
# 85                 0.522907                  0.548394               0.553012
# 84                 0.522907                  0.548394               0.553012
# 92                 0.522907                  0.548394               0.553012
# 90                 0.522907                  0.548394               0.553012
# 97                 0.522984                  0.548706               0.553012
# 93                 0.522907                  0.548394               0.553012
# 89                 0.522907                  0.548394               0.553012
# 75                 0.522907                  0.548394               0.553012
# 99                 0.522907                  0.548394               0.553012
# 101                0.522907                  0.548394               0.553012
# 88                 0.522907                  0.548394               0.553012
# 81                 0.522907                  0.548394               0.553012
# 82                 0.522907                  0.548394               0.553012
# 77                 0.522907                  0.548394               0.553012
# 74                 0.522907                  0.548394               0.553012
# 116                0.523489                  0.549814               0.553012
# 73                 0.522907                  0.548394               0.553012
# 49                 0.522337                  0.547970               0.552345
# 55                 0.522337                  0.547970               0.552345
# 54                 0.522337                  0.547970               0.552345
# 52                 0.522337                  0.547970               0.552345
# 50                 0.522337                  0.547970               0.552345
# 8                  0.522337                  0.547970               0.552345
# 87                 0.522337                  0.547970               0.552345
# 57                 0.522337                  0.547970               0.552345
# 56                 0.522337                  0.547970               0.552345
# 63                 0.522337                  0.547970               0.552345
# 62                 0.522337                  0.547970               0.552345
# 65                 0.522337                  0.547970               0.552345
# 64                 0.522337                  0.547970               0.552345
# 67                 0.522337                  0.547970               0.552345
# 69                 0.522337                  0.547970               0.552345
# 70                 0.522337                  0.547970               0.552345
# 71                 0.522337                  0.547970               0.552345
# 59                 0.522337                  0.547970               0.552345
# 86                 0.522337                  0.547970               0.552345
# 78                 0.522337                  0.547970               0.552345
# 79                 0.522337                  0.547970               0.552345
# 72                 0.522337                  0.547970               0.552345
# 61                 0.522337                  0.547970               0.552345
# 94                 0.522337                  0.547970               0.552345
# 91                 0.522337                  0.547970               0.552345
# 103                0.522337                  0.547970               0.552345
# 102                0.522337                  0.547970               0.552345
# 100                0.522722                  0.549082               0.552345
# 95                 0.522337                  0.547970               0.552345
# 111                0.522337                  0.547970               0.552345
# 110                0.522337                  0.547970               0.552345
# 118                0.522337                  0.547970               0.552345
# 119                0.522337                  0.547970               0.552345

# %% [markdown]
# #### BYOL

# %%
df_rbfn_byol = df_rbfn[df_rbfn["architecture"] == "byol"]
df_rbfn_byol = df_rbfn_byol.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_byol
# Out:
#    projection_head_type architecture  projection_head_num_layers  \
# 31                 rbfn         byol                           2
# 32                 rbfn         byol                           2
# 40                 rbfn         byol                           2
# 39                 rbfn         byol                           2
# 47                 rbfn         byol                           2
# 48                 rbfn         byol                           2
# 25                 rbfn         byol                           2
# 26                 rbfn         byol                           2
# 29                 rbfn         byol                           2
# 30                 rbfn         byol                           2
# 27                 rbfn         byol                           2
# 28                 rbfn         byol                           2
# 36                 rbfn         byol                           2
# 35                 rbfn         byol                           2
# 33                 rbfn         byol                           2
# 34                 rbfn         byol                           2
# 37                 rbfn         byol                           2
# 38                 rbfn         byol                           2
# 41                 rbfn         byol                           2
# 42                 rbfn         byol                           2
# 44                 rbfn         byol                           2
# 43                 rbfn         byol                           2
# 46                 rbfn         byol                           2
# 45                 rbfn         byol                           2
#
#     rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 31                               128                             gaussian
# 32                               128                             gaussian
# 40                               256                             gaussian
# 39                               256                             gaussian
# 47                               512                             gaussian
# 48                               512                             gaussian
# 25                               128                                  tps
# 26                               128                                  tps
# 29                               128                 inverse_multiquadric
# 30                               128                 inverse_multiquadric
# 27                               128                         multiquadric
# 28                               128                         multiquadric
# 36                               256                         multiquadric
# 35                               256                         multiquadric
# 33                               256                                  tps
# 34                               256                                  tps
# 37                               256                 inverse_multiquadric
# 38                               256                 inverse_multiquadric
# 41                               512                                  tps
# 42                               512                                  tps
# 44                               512                         multiquadric
# 43                               512                         multiquadric
# 46                               512                 inverse_multiquadric
# 45                               512                 inverse_multiquadric
#
#     rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 31                           False                 0.554237
# 32                            True                 0.554237
# 40                            True                 0.554237
# 39                           False                 0.554237
# 47                           False                 0.554237
# 48                            True                 0.554237
# 25                           False                 0.020000
# 26                            True                 0.020000
# 29                           False                 0.020000
# 30                            True                 0.020000
# 27                           False                 0.020000
# 28                            True                 0.020000
# 36                            True                 0.020000
# 35                           False                 0.020000
# 33                           False                 0.020000
# 34                            True                 0.020000
# 37                           False                 0.020000
# 38                            True                 0.020000
# 41                           False                 0.020000
# 42                            True                 0.020000
# 44                            True                 0.020000
# 43                           False                 0.020000
# 46                            True                 0.020000
# 45                           False                 0.020000
#
#     test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 31                0.526032                  0.552392               0.554237
# 32                0.526032                  0.552392               0.554237
# 40                0.526032                  0.552392               0.554237
# 39                0.526032                  0.552392               0.554237
# 47                0.526032                  0.552392               0.554237
# 48                0.526032                  0.552392               0.554237
# 25                0.000786                  0.000401               0.020000
# 26                0.000786                  0.000401               0.020000
# 29                0.000786                  0.000401               0.020000
# 30                0.000786                  0.000401               0.020000
# 27                0.000786                  0.000401               0.020000
# 28                0.000786                  0.000401               0.020000
# 36                0.000786                  0.000401               0.020000
# 35                0.000786                  0.000401               0.020000
# 33                0.000786                  0.000401               0.020000
# 34                0.000786                  0.000401               0.020000
# 37                0.000786                  0.000401               0.020000
# 38                0.000786                  0.000401               0.020000
# 41                0.000786                  0.000401               0.020000
# 42                0.000786                  0.000401               0.020000
# 44                0.000786                  0.000401               0.020000
# 43                0.000786                  0.000401               0.020000
# 46                0.000786                  0.000401               0.020000
# 45                0.000786                  0.000401               0.020000

# %% [markdown]
# #### SwAV

# %%
df_rbfn_swav = df_rbfn[df_rbfn["architecture"] == "swav"]
df_rbfn_swav = df_rbfn_swav.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_swav
# Out:
#    projection_head_type architecture  projection_head_num_layers  \
# 9                  rbfn         swav                           2
# 6                  rbfn         swav                           2
# 16                 rbfn         swav                           2
# 7                  rbfn         swav                           2
# 23                 rbfn         swav                           2
# 15                 rbfn         swav                           2
# 24                 rbfn         swav                           2
# 17                 rbfn         swav                           2
# 21                 rbfn         swav                           2
# 0                  rbfn         swav                           2
# 11                 rbfn         swav                           2
# 10                 rbfn         swav                           2
# 18                 rbfn         swav                           2
# 13                 rbfn         swav                           2
# 1                  rbfn         swav                           2
# 14                 rbfn         swav                           2
# 12                 rbfn         swav                           2
# 22                 rbfn         swav                           2
# 20                 rbfn         swav                           2
# 3                  rbfn         swav                           2
# 4                  rbfn         swav                           2
# 5                  rbfn         swav                           2
# 2                  rbfn         swav                           2
# 19                 rbfn         swav                           2
#
#     rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 9                                128                                  tps
# 6                                512                             gaussian
# 16                               128                             gaussian
# 7                                512                             gaussian
# 23                               256                             gaussian
# 15                               128                             gaussian
# 24                               256                             gaussian
# 17                               256                                  tps
# 21                               256                 inverse_multiquadric
# 0                                512                                  tps
# 11                               128                         multiquadric
# 10                               128                                  tps
# 18                               256                                  tps
# 13                               128                 inverse_multiquadric
# 1                                512                                  tps
# 14                               128                 inverse_multiquadric
# 12                               128                         multiquadric
# 22                               256                 inverse_multiquadric
# 20                               256                         multiquadric
# 3                                512                         multiquadric
# 4                                512                 inverse_multiquadric
# 5                                512                 inverse_multiquadric
# 2                                512                         multiquadric
# 19                               256                         multiquadric
#
#     rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 9                            False                 0.492334
# 6                            False                 0.425599
# 16                            True                 0.425599
# 7                             True                 0.425599
# 23                           False                 0.425599
# 15                           False                 0.425599
# 24                            True                 0.425599
# 17                           False                 0.413665
# 21                           False                 0.412005
# 0                            False                 0.382277
# 11                           False                 0.345093
# 10                            True                 0.334044
# 18                            True                 0.289981
# 13                           False                 0.280279
# 1                             True                 0.214943
# 14                            True                 0.203873
# 12                            True                 0.185936
# 22                            True                 0.107461
# 20                            True                 0.061164
# 3                             True                 0.020000
# 4                            False                 0.020000
# 5                             True                 0.020000
# 2                            False                 0.020000
# 19                           False                 0.020000
#
#     test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 9                 0.439310                  0.455527               0.492334
# 6                 0.396867                  0.451016               0.425599
# 16                0.396867                  0.451016               0.425599
# 7                 0.396867                  0.451016               0.425599
# 23                0.396867                  0.451016               0.425599
# 15                0.396867                  0.451016               0.425599
# 24                0.396867                  0.451016               0.425599
# 17                0.361235                  0.372741               0.413665
# 21                0.368017                  0.404780               0.412005
# 0                 0.321057                  0.363173               0.382277
# 11                0.283733                  0.330551               0.345093
# 10                0.289785                  0.333993               0.334044
# 18                0.247142                  0.293109               0.289981
# 13                0.237971                  0.314242               0.280279
# 1                 0.155628                  0.208803               0.214943
# 14                0.155457                  0.183435               0.203873
# 12                0.118844                  0.151059               0.185936
# 22                0.045060                  0.058452               0.107461
# 20                0.024268                  0.030095               0.061164
# 3                 0.000786                  0.000401               0.020000
# 4                 0.000786                  0.000401               0.020000
# 5                 0.000786                  0.000401               0.020000
# 2                 0.000786                  0.000401               0.020000
# 19                0.000786                  0.000401               0.020000

# %% [markdown]
# ## Comparison by Architecture

# %% [markdown]
# ### Top-1 Accuracy

# %%
METRIC_COL = "test_MulticlassAccuracy"

# %% [markdown]
# #### SimCLR

# %%
df_default_rbfn_simclr = pd.concat([df_default_simclr.head(1), df_rbfn_simclr.head(1)])
df_default_rbfn_simclr
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 8                default       simclr                           2
# 144                 rbfn       simclr                           4
#
#      test_MulticlassAccuracy  test_MulticlassF1Score  \
# 8                   0.542997                0.521593
# 144                 0.542519                0.513374
#
#      test_MulticlassPrecision  test_MulticlassRecall  \
# 8                    0.535298               0.542997
# 144                  0.540129               0.542519
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 8                                 NaN                                  NaN
# 144                             128.0                                  tps
#
#     rbfn_projection_head_normalize
# 8                              NaN
# 144                          False

# %%
rbfn_default_diff_simclr = df_default_rbfn_simclr[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_simclr * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): -0.05 %

# %% [markdown]
# #### SimSiam

# %%
df_default_rbfn_simsiam = pd.concat([df_default_simsiam.head(1), df_rbfn_simsiam.head(1)])
df_default_rbfn_simsiam
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 5                default      simsiam                           2
# 121                 rbfn      simsiam                           2
#
#      test_MulticlassAccuracy  test_MulticlassF1Score  \
# 5                   0.573259                0.546128
# 121                 0.551033                0.522133
#
#      test_MulticlassPrecision  test_MulticlassRecall  \
# 5                    0.562275               0.573259
# 121                  0.552446               0.551033
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 5                                 NaN                                  NaN
# 121                             128.0                                  tps
#
#     rbfn_projection_head_normalize
# 5                              NaN
# 121                           True

# %%
rbfn_default_diff_simsiam = df_default_rbfn_simsiam[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_simsiam * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): -2.22 %

# %% [markdown]
# #### MoCo

# %%
df_default_rbfn_moco = pd.concat([df_default_moco.head(1), df_rbfn_moco.head(1)])
df_default_rbfn_moco.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_default_rbfn_moco
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 3                default         moco                           3
# 104                 rbfn         moco                           2
#
#      test_MulticlassAccuracy  test_MulticlassF1Score  \
# 3                   0.577996                0.554181
# 104                 0.555013                0.525515
#
#      test_MulticlassPrecision  test_MulticlassRecall  \
# 3                    0.560400               0.577996
# 104                  0.550786               0.555013
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 3                                 NaN                                  NaN
# 104                             256.0                                  tps
#
#     rbfn_projection_head_normalize
# 3                              NaN
# 104                          False

# %%
rbfn_default_diff_moco = df_default_rbfn_moco[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_moco * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): -2.3 %

# %% [markdown]
# #### BYOL

# %%
df_default_rbfn_byol = pd.concat([df_default_byol.head(1), df_rbfn_byol.head(1)])
df_default_rbfn_byol.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_default_rbfn_byol
# Out:
#    projection_head_type architecture  projection_head_num_layers  \
# 31                 rbfn         byol                           2
# 1               default         byol                           2
#
#     test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 31                 0.554237                0.526032                  0.552392
# 1                  0.523573                0.491362                  0.552817
#
#     test_MulticlassRecall  rbfn_projection_head_num_kernels  \
# 31               0.554237                             128.0
# 1                0.523573                               NaN
#
#    rbfn_projection_head_radial_function rbfn_projection_head_normalize
# 31                             gaussian                          False
# 1                                   NaN                            NaN

# %%
rbfn_default_diff_byol = df_default_rbfn_byol[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_byol * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): -3.07 %

# %% [markdown]
# #### SwAV

# %%
df_default_rbfn_swav = pd.concat([df_default_swav.head(1), df_rbfn_swav.head(1)])
df_default_rbfn_swav.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_default_rbfn_swav
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 0              default         swav                           2
# 9                 rbfn         swav                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 0                 0.513985                0.472366                  0.475897
# 9                 0.492334                0.439310                  0.455527
#
#    test_MulticlassRecall  rbfn_projection_head_num_kernels  \
# 0               0.513985                               NaN
# 9               0.492334                             128.0
#
#   rbfn_projection_head_radial_function rbfn_projection_head_normalize
# 0                                  NaN                            NaN
# 9                                  tps                          False

# %%
rbfn_default_diff_swav = df_default_rbfn_swav[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_swav * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): -2.17 %

# %% [markdown]
# #### Peak Performance Across Architectures

# %%
df_default_best = pd.concat([
    df_default_simclr.head(1),
    df_default_simsiam.head(1),
    df_default_moco.head(1),
    df_default_byol.head(1),
    df_default_swav.head(1)  
])
df_default_best.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_default_best
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 3              default         moco                           3
# 5              default      simsiam                           2
# 8              default       simclr                           2
# 1              default         byol                           2
# 0              default         swav                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 3                 0.577996                0.554181                  0.560400
# 5                 0.573259                0.546128                  0.562275
# 8                 0.542997                0.521593                  0.535298
# 1                 0.523573                0.491362                  0.552817
# 0                 0.513985                0.472366                  0.475897
#
#    test_MulticlassRecall
# 3               0.577996
# 5               0.573259
# 8               0.542997
# 1               0.523573
# 0               0.513985

# %%
df_default_best[METRICS].mean()
# Out:
# test_MulticlassAccuracy     0.546362
# test_MulticlassF1Score      0.517126
# test_MulticlassPrecision    0.537337
# test_MulticlassRecall       0.546362
# dtype: float64

# %%
default_best_mean = df_default_best[[METRIC_COL]].mean().iloc[-1]
print(f"Mean {METRIC_COL} (default):", round(default_best_mean * 100, 2), "%")
# Out:
# Mean test_MulticlassAccuracy (default): 54.64 %

# %%
df_rbfn_best = pd.concat([
    df_rbfn_simclr.head(1),
    df_rbfn_simsiam.head(1),
    df_rbfn_moco.head(1),
    df_rbfn_byol.head(1),
    df_rbfn_swav.head(1)
])
df_rbfn_best.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_rbfn_best
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 104                 rbfn         moco                           2
# 31                  rbfn         byol                           2
# 121                 rbfn      simsiam                           2
# 144                 rbfn       simclr                           4
# 9                   rbfn         swav                           2
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 104                               256                                  tps
# 31                                128                             gaussian
# 121                               128                                  tps
# 144                               128                                  tps
# 9                                 128                                  tps
#
#      rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 104                           False                 0.555013
# 31                            False                 0.554237
# 121                            True                 0.551033
# 144                           False                 0.542519
# 9                             False                 0.492334
#
#      test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 104                0.525515                  0.550786               0.555013
# 31                 0.526032                  0.552392               0.554237
# 121                0.522133                  0.552446               0.551033
# 144                0.513374                  0.540129               0.542519
# 9                  0.439310                  0.455527               0.492334

# %%
df_rbfn_best[METRICS].mean()
# Out:
# test_MulticlassAccuracy     0.539027
# test_MulticlassF1Score      0.505273
# test_MulticlassPrecision    0.530256
# test_MulticlassRecall       0.539027
# dtype: float64

# %%
rbfn_best_mean = df_rbfn_best[[METRIC_COL]].mean().iloc[-1]
print(f"Mean {METRIC_COL} (RBFN):", round(rbfn_best_mean * 100, 2), "%")
# Out:
# Mean test_MulticlassAccuracy (RBFN): 53.9 %

# %%
print(f"Diff. mean {METRIC_COL} RBFN <-> default:", round((rbfn_best_mean - default_best_mean) * 100, 2), "%")
# Out:
# Diff. mean test_MulticlassAccuracy RBFN <-> default: -0.73 %

# %%
#### Average Performance Across Architectures

# %%
df_default_average = pd.concat([
    df_default_moco[METRICS].mean().to_frame().T.assign(architecture="moco", projection_head_type="default"),
    df_default_simclr[METRICS].mean().to_frame().T.assign(architecture="simclr", projection_head_type="default"),
    df_default_byol[METRICS].mean().to_frame().T.assign(architecture="byol", projection_head_type="default"),
    df_default_swav[METRICS].mean().to_frame().T.assign(architecture="swav", projection_head_type="default"),
    df_default_simsiam[METRICS].mean().to_frame().T.assign(architecture="simsiam", projection_head_type="default"),
], ignore_index=True)

df_default_average
# Out:
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 0                 0.577099                0.553867                  0.561431
# 1                 0.538011                0.517406                  0.533112
# 2                 0.523573                0.491362                  0.552817
# 3                 0.513985                0.472366                  0.475897
# 4                 0.573259                0.546128                  0.562275
#
#    test_MulticlassRecall architecture projection_head_type
# 0               0.577099         moco              default
# 1               0.538011       simclr              default
# 2               0.523573         byol              default
# 3               0.513985         swav              default
# 4               0.573259      simsiam              default

# %%
df_default_average[METRICS].mean()
# Out:
# test_MulticlassAccuracy     0.545185
# test_MulticlassF1Score      0.516226
# test_MulticlassPrecision    0.537106
# test_MulticlassRecall       0.545185
# dtype: float64

# %%
df_rbfn_average = pd.concat([
    df_rbfn_moco[METRICS].mean().to_frame().T.assign(architecture="moco", projection_head_type="rbfn"),
    df_rbfn_simclr[METRICS].mean().to_frame().T.assign(architecture="simclr", projection_head_type="rbfn"),
    df_rbfn_byol[METRICS].mean().to_frame().T.assign(architecture="byol", projection_head_type="rbfn"),
    df_rbfn_swav[METRICS].mean().to_frame().T.assign(architecture="swav", projection_head_type="rbfn"),
    df_rbfn_simsiam[METRICS].mean().to_frame().T.assign(architecture="simsiam", projection_head_type="rbfn"),
], ignore_index=True)

df_rbfn_average
# Out:
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 0                 0.552799                0.522791                  0.548360
# 1                 0.308286                0.277563                  0.296429
# 2                 0.153559                0.132098                  0.138399
# 3                 0.265694                0.226360                  0.258669
# 4                 0.548829                0.520666                  0.551966
#
#    test_MulticlassRecall architecture projection_head_type
# 0               0.552799         moco                 rbfn
# 1               0.308286       simclr                 rbfn
# 2               0.153559         byol                 rbfn
# 3               0.265694         swav                 rbfn
# 4               0.548829      simsiam                 rbfn

# %%
df_rbfn_average[METRICS].mean()
# Out:
# test_MulticlassAccuracy     0.365834
# test_MulticlassF1Score      0.335896
# test_MulticlassPrecision    0.358764
# test_MulticlassRecall       0.365834
# dtype: float64

# %% [markdown]
# ### SHAP Analysis of RBFN Parameters

# %%
X = df_rbfn.drop(columns=[
    MAIN_METRIC,
    "test_MulticlassF1Score",
    "test_MulticlassPrecision",
    "test_MulticlassRecall",
    "projection_head_type",
    "architecture"])
y = df_rbfn[MAIN_METRIC]

# %%
X = pd.get_dummies(X, drop_first=False)
bool_cols = X.select_dtypes(include=["bool"]).columns
X[bool_cols] = X[bool_cols].astype(int)

# %%
xgb_model = XGBRegressor()
xgb_model.fit(X, y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
explainer = shap.Explainer(xgb_model, X)
shap_values = explainer(X)

# %%
shap_df = pd.DataFrame(shap_values.values, columns=X.columns)
importance_table = pd.DataFrame({
    "mean_abs_shap": shap_df.abs().mean(),
    "positive_mean": shap_df.where(shap_df > 0).mean(),
    "negative_mean": shap_df.where(shap_df < 0).mean(),
    "std": shap_df.std()
})
importance_table = importance_table.sort_values("mean_abs_shap", ascending=False)
importance_table.round(2)
# Out:
#                                                     mean_abs_shap  \
# rbfn_projection_head_radial_function_gaussian                0.07
# rbfn_projection_head_radial_function_tps                     0.02
# projection_head_num_layers                                   0.02
# rbfn_projection_head_normalize                               0.02
# rbfn_projection_head_num_kernels                             0.01
# rbfn_projection_head_radial_function_inverse_mu...           0.00
# rbfn_projection_head_radial_function_multiquadric            0.00
#
#                                                     positive_mean  \
# rbfn_projection_head_radial_function_gaussian                0.15
# rbfn_projection_head_radial_function_tps                     0.05
# projection_head_num_layers                                   0.03
# rbfn_projection_head_normalize                               0.02
# rbfn_projection_head_num_kernels                             0.01
# rbfn_projection_head_radial_function_inverse_mu...           0.00
# rbfn_projection_head_radial_function_multiquadric            0.00
#
#                                                     negative_mean   std
# rbfn_projection_head_radial_function_gaussian               -0.04  0.09
# rbfn_projection_head_radial_function_tps                    -0.01  0.03
# projection_head_num_layers                                  -0.01  0.03
# rbfn_projection_head_normalize                              -0.02  0.02
# rbfn_projection_head_num_kernels                            -0.01  0.01
# rbfn_projection_head_radial_function_inverse_mu...          -0.00  0.00
# rbfn_projection_head_radial_function_multiquadric           -0.00  0.00

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)
