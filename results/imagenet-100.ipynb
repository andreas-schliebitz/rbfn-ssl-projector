# %% [markdown]
# # ImageNet100

# %%
import shap
import pandas as pd
import numpy as np

from pathlib import Path
from xgboost import XGBRegressor

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
DATASET_NAME = "imagenet-100"
METRICS = ["test_MulticlassAccuracy", "test_MulticlassF1Score", "test_MulticlassPrecision", "test_MulticlassRecall"]
MAIN_METRIC = "test_MulticlassAccuracy"

# %%
RESULTS_PATH = Path(".").resolve()

# %% [markdown]
# ## Default Projector

# %%
DEFAULT_EVAL_RESULTS_PATH = RESULTS_PATH.joinpath(DATASET_NAME, "default", f"rbfn-ssl-projector-default-eval_{DATASET_NAME}.csv")
print(DEFAULT_EVAL_RESULTS_PATH)
DEFAULT_RANGES = [
    "architecture",
    "projection_head_num_layers"
]
# Out:
# /cluster/user/aschlieb/promotion/code/rbfn-ssl-projector/results/imagenet-100/default/rbfn-ssl-projector-default-eval_imagenet-100.csv

# %%
df_default = pd.read_csv(DEFAULT_EVAL_RESULTS_PATH)
df_default = df_default[["projection_head_type"] + DEFAULT_RANGES + METRICS]

# %% [markdown]
# ### By Architecture

# %% [markdown]
# #### SimCLR

# %%
df_default_simclr = df_default[df_default["architecture"] == "simclr"]
df_default_simclr = df_default_simclr.sort_values(by=MAIN_METRIC, ascending=False)
df_default_simclr
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 6              default       simclr                           4
# 7              default       simclr                           3
# 8              default       simclr                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 6                 0.883743                0.883998                  0.888626
# 7                 0.881572                0.881581                  0.886465
# 8                 0.876641                0.877157                  0.882367
#
#    test_MulticlassRecall
# 6               0.883743
# 7               0.881572
# 8               0.876641

# %% [markdown]
# #### SimSiam

# %%
df_default_simsiam = df_default[df_default["architecture"] == "simsiam"]
df_default_simsiam = df_default_simsiam.sort_values(by=MAIN_METRIC, ascending=False)
df_default_simsiam
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 5              default      simsiam                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 5                 0.920327                 0.92083                  0.925832
#
#    test_MulticlassRecall
# 5               0.920327

# %% [markdown]
# #### MoCo

# %%
df_default_moco = df_default[df_default["architecture"] == "moco"]
df_default_moco = df_default_moco.sort_values(by=MAIN_METRIC, ascending=False)
df_default_moco
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 2              default         moco                           4
# 3              default         moco                           3
# 4              default         moco                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 2                 0.919822                0.920365                  0.924260
# 3                 0.916908                0.917451                  0.921409
# 4                 0.915585                0.916136                  0.920038
#
#    test_MulticlassRecall
# 2               0.919822
# 3               0.916908
# 4               0.915585

# %% [markdown]
# #### BYOL

# %%
df_default_byol = df_default[df_default["architecture"] == "byol"]
df_default_byol = df_default_byol.sort_values(by=MAIN_METRIC, ascending=False)
df_default_byol
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 1              default         byol                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 1                 0.889295                0.884485                  0.895701
#
#    test_MulticlassRecall
# 1               0.889295

# %% [markdown]
# #### SwAV

# %%
df_default_swav = df_default[df_default["architecture"] == "swav"]
df_default_swav = df_default_swav.sort_values(by=MAIN_METRIC, ascending=False)
df_default_swav
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 0              default         swav                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 0                 0.876979                0.875282                  0.885032
#
#    test_MulticlassRecall
# 0               0.876979

# %% [markdown]
# ## RBFN Projector

# %%
RBFN_EVAL_RESULTS_PATH = RESULTS_PATH.joinpath(DATASET_NAME, "rbfn", f"rbfn-ssl-projector-rbfn-eval_{DATASET_NAME}.csv")
print(RBFN_EVAL_RESULTS_PATH)

RBFN_RANGES = [
    "architecture",
    "projection_head_num_layers",
    "rbfn_projection_head_num_kernels",
    "rbfn_projection_head_radial_function",
    "rbfn_projection_head_normalize"
]
# Out:
# /cluster/user/aschlieb/promotion/code/rbfn-ssl-projector/results/imagenet-100/rbfn/rbfn-ssl-projector-rbfn-eval_imagenet-100.csv

# %% [markdown]
# ### By Architecture

# %%
df_rbfn = pd.read_csv(RBFN_EVAL_RESULTS_PATH)
df_rbfn = df_rbfn[["projection_head_type"] + RBFN_RANGES + METRICS]

# %% [markdown]
# #### SimCLR

# %%
df_rbfn_simclr = df_rbfn[df_rbfn["architecture"] == "simclr"]
df_rbfn_simclr = df_rbfn_simclr.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_simclr
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 144                 rbfn       simclr                           4
# 151                 rbfn       simclr                           4
# 150                 rbfn       simclr                           4
# 167                 rbfn       simclr                           4
# 160                 rbfn       simclr                           4
# 158                 rbfn       simclr                           4
# 159                 rbfn       simclr                           4
# 152                 rbfn       simclr                           4
# 206                 rbfn       simclr                           2
# 207                 rbfn       simclr                           2
# 215                 rbfn       simclr                           2
# 214                 rbfn       simclr                           2
# 198                 rbfn       simclr                           2
# 166                 rbfn       simclr                           4
# 175                 rbfn       simclr                           3
# 174                 rbfn       simclr                           3
# 182                 rbfn       simclr                           3
# 183                 rbfn       simclr                           3
# 191                 rbfn       simclr                           3
# 190                 rbfn       simclr                           3
# 199                 rbfn       simclr                           2
# 165                 rbfn       simclr                           4
# 163                 rbfn       simclr                           4
# 155                 rbfn       simclr                           4
# 157                 rbfn       simclr                           4
# 147                 rbfn       simclr                           4
# 149                 rbfn       simclr                           4
# 161                 rbfn       simclr                           4
# 192                 rbfn       simclr                           2
# 200                 rbfn       simclr                           2
# 208                 rbfn       simclr                           2
# 194                 rbfn       simclr                           2
# 153                 rbfn       simclr                           4
# 202                 rbfn       simclr                           2
# 210                 rbfn       simclr                           2
# 193                 rbfn       simclr                           2
# 201                 rbfn       simclr                           2
# 212                 rbfn       simclr                           2
# 204                 rbfn       simclr                           2
# 209                 rbfn       simclr                           2
# 197                 rbfn       simclr                           2
# 196                 rbfn       simclr                           2
# 195                 rbfn       simclr                           2
# 178                 rbfn       simclr                           3
# 170                 rbfn       simclr                           3
# 203                 rbfn       simclr                           2
# 145                 rbfn       simclr                           4
# 176                 rbfn       simclr                           3
# 205                 rbfn       simclr                           2
# 186                 rbfn       simclr                           3
# 168                 rbfn       simclr                           3
# 146                 rbfn       simclr                           4
# 184                 rbfn       simclr                           3
# 171                 rbfn       simclr                           3
# 173                 rbfn       simclr                           3
# 148                 rbfn       simclr                           4
# 156                 rbfn       simclr                           4
# 154                 rbfn       simclr                           4
# 211                 rbfn       simclr                           2
# 188                 rbfn       simclr                           3
# 172                 rbfn       simclr                           3
# 180                 rbfn       simclr                           3
# 162                 rbfn       simclr                           4
# 164                 rbfn       simclr                           4
# 213                 rbfn       simclr                           2
# 181                 rbfn       simclr                           3
# 185                 rbfn       simclr                           3
# 177                 rbfn       simclr                           3
# 169                 rbfn       simclr                           3
# 179                 rbfn       simclr                           3
# 187                 rbfn       simclr                           3
# 189                 rbfn       simclr                           3
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 144                               128                                  tps
# 151                               128                             gaussian
# 150                               128                             gaussian
# 167                               512                             gaussian
# 160                               512                                  tps
# 158                               256                             gaussian
# 159                               256                             gaussian
# 152                               256                                  tps
# 206                               256                             gaussian
# 207                               256                             gaussian
# 215                               512                             gaussian
# 214                               512                             gaussian
# 198                               128                             gaussian
# 166                               512                             gaussian
# 175                               128                             gaussian
# 174                               128                             gaussian
# 182                               256                             gaussian
# 183                               256                             gaussian
# 191                               512                             gaussian
# 190                               512                             gaussian
# 199                               128                             gaussian
# 165                               512                 inverse_multiquadric
# 163                               512                         multiquadric
# 155                               256                         multiquadric
# 157                               256                 inverse_multiquadric
# 147                               128                         multiquadric
# 149                               128                 inverse_multiquadric
# 161                               512                                  tps
# 192                               128                                  tps
# 200                               256                                  tps
# 208                               512                                  tps
# 194                               128                         multiquadric
# 153                               256                                  tps
# 202                               256                         multiquadric
# 210                               512                         multiquadric
# 193                               128                                  tps
# 201                               256                                  tps
# 212                               512                 inverse_multiquadric
# 204                               256                 inverse_multiquadric
# 209                               512                                  tps
# 197                               128                 inverse_multiquadric
# 196                               128                 inverse_multiquadric
# 195                               128                         multiquadric
# 178                               256                         multiquadric
# 170                               128                         multiquadric
# 203                               256                         multiquadric
# 145                               128                                  tps
# 176                               256                                  tps
# 205                               256                 inverse_multiquadric
# 186                               512                         multiquadric
# 168                               128                                  tps
# 146                               128                         multiquadric
# 184                               512                                  tps
# 171                               128                         multiquadric
# 173                               128                 inverse_multiquadric
# 148                               128                 inverse_multiquadric
# 156                               256                 inverse_multiquadric
# 154                               256                         multiquadric
# 211                               512                         multiquadric
# 188                               512                 inverse_multiquadric
# 172                               128                 inverse_multiquadric
# 180                               256                 inverse_multiquadric
# 162                               512                         multiquadric
# 164                               512                 inverse_multiquadric
# 213                               512                 inverse_multiquadric
# 181                               256                 inverse_multiquadric
# 185                               512                                  tps
# 177                               256                                  tps
# 169                               128                                  tps
# 179                               256                         multiquadric
# 187                               512                         multiquadric
# 189                               512                 inverse_multiquadric
#
#      rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 144                           False                 0.921659
# 151                            True                 0.921659
# 150                           False                 0.921659
# 167                            True                 0.921659
# 160                           False                 0.921659
# 158                           False                 0.921659
# 159                            True                 0.921659
# 152                           False                 0.921659
# 206                           False                 0.921659
# 207                            True                 0.921659
# 215                            True                 0.921659
# 214                           False                 0.921659
# 198                           False                 0.921659
# 166                           False                 0.921659
# 175                            True                 0.921659
# 174                           False                 0.921659
# 182                           False                 0.921659
# 183                            True                 0.921659
# 191                            True                 0.921659
# 190                           False                 0.921659
# 199                            True                 0.921659
# 165                            True                 0.913589
# 163                            True                 0.911600
# 155                            True                 0.901280
# 157                            True                 0.899943
# 147                            True                 0.897752
# 149                            True                 0.887282
# 161                            True                 0.875592
# 192                           False                 0.843424
# 200                           False                 0.834773
# 208                           False                 0.824046
# 194                           False                 0.817601
# 153                            True                 0.811419
# 202                           False                 0.801287
# 210                           False                 0.779023
# 193                            True                 0.773119
# 201                            True                 0.739901
# 212                           False                 0.735746
# 204                           False                 0.723220
# 209                            True                 0.722463
# 197                            True                 0.695321
# 196                           False                 0.678514
# 195                            True                 0.661082
# 178                           False                 0.659051
# 170                           False                 0.647575
# 203                            True                 0.641871
# 145                            True                 0.641227
# 176                           False                 0.618030
# 205                            True                 0.610545
# 186                           False                 0.562147
# 168                           False                 0.554411
# 146                           False                 0.414570
# 184                           False                 0.405509
# 171                            True                 0.121525
# 173                            True                 0.106481
# 148                           False                 0.010000
# 156                           False                 0.010000
# 154                           False                 0.010000
# 211                            True                 0.010000
# 188                           False                 0.010000
# 172                           False                 0.010000
# 180                           False                 0.010000
# 162                           False                 0.010000
# 164                           False                 0.010000
# 213                            True                 0.010000
# 181                            True                 0.009424
# 185                            True                 0.009074
# 177                            True                 0.008889
# 169                            True                 0.008333
# 179                            True                 0.008135
# 187                            True                 0.007953
# 189                            True                 0.007209
#
#      test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 144                0.918458                  0.929467               0.921659
# 151                0.918458                  0.929467               0.921659
# 150                0.918458                  0.929467               0.921659
# 167                0.918458                  0.929467               0.921659
# 160                0.918458                  0.929467               0.921659
# 158                0.918458                  0.929467               0.921659
# 159                0.918458                  0.929467               0.921659
# 152                0.918458                  0.929467               0.921659
# 206                0.918458                  0.929467               0.921659
# 207                0.918458                  0.929467               0.921659
# 215                0.918458                  0.929467               0.921659
# 214                0.918458                  0.929467               0.921659
# 198                0.918458                  0.929467               0.921659
# 166                0.918458                  0.929467               0.921659
# 175                0.918458                  0.929467               0.921659
# 174                0.918458                  0.929467               0.921659
# 182                0.918458                  0.929467               0.921659
# 183                0.918458                  0.929467               0.921659
# 191                0.918458                  0.929467               0.921659
# 190                0.918458                  0.929467               0.921659
# 199                0.918458                  0.929467               0.921659
# 165                0.909820                  0.912608               0.913589
# 163                0.907862                  0.910402               0.911600
# 155                0.898169                  0.904074               0.901280
# 157                0.897140                  0.904087               0.899943
# 147                0.894524                  0.899953               0.897752
# 149                0.884090                  0.891118               0.887282
# 161                0.872488                  0.882447               0.875592
# 192                0.843622                  0.849441               0.843424
# 200                0.835009                  0.841156               0.834773
# 208                0.823186                  0.831414               0.824046
# 194                0.817432                  0.825167               0.817601
# 153                0.809569                  0.844353               0.811419
# 202                0.799609                  0.807970               0.801287
# 210                0.777834                  0.788584               0.779023
# 193                0.772435                  0.783943               0.773119
# 201                0.737213                  0.754771               0.739901
# 212                0.725709                  0.747279               0.735746
# 204                0.715399                  0.735187               0.723220
# 209                0.718443                  0.743656               0.722463
# 197                0.690939                  0.707608               0.695321
# 196                0.665550                  0.690792               0.678514
# 195                0.653299                  0.669357               0.661082
# 178                0.645451                  0.713615               0.659051
# 170                0.635602                  0.683732               0.647575
# 203                0.629270                  0.673477               0.641871
# 145                0.628879                  0.734322               0.641227
# 176                0.590927                  0.652134               0.618030
# 205                0.589155                  0.633514               0.610545
# 186                0.540688                  0.674349               0.562147
# 168                0.516741                  0.647655               0.554411
# 146                0.368473                  0.425445               0.414570
# 184                0.342933                  0.486426               0.405509
# 171                0.096174                  0.175170               0.121525
# 173                0.083074                  0.155844               0.106481
# 148                0.000203                  0.000102               0.010000
# 156                0.000203                  0.000102               0.010000
# 154                0.000203                  0.000102               0.010000
# 211                0.000203                  0.000102               0.010000
# 188                0.000203                  0.000102               0.010000
# 172                0.000203                  0.000102               0.010000
# 180                0.000203                  0.000102               0.010000
# 162                0.000203                  0.000102               0.010000
# 164                0.000203                  0.000102               0.010000
# 213                0.000203                  0.000102               0.010000
# 181                0.002130                  0.001992               0.009424
# 185                0.000239                  0.000123               0.009074
# 177                0.000436                  0.000226               0.008889
# 169                0.000605                  0.000337               0.008333
# 179                0.002217                  0.011347               0.008135
# 187                0.001114                  0.000783               0.007953
# 189                0.001080                  0.000729               0.007209

# %% [markdown]
# #### SimSiam

# %%
df_rbfn_simsiam = df_rbfn[df_rbfn["architecture"] == "simsiam"]
df_rbfn_simsiam = df_rbfn_simsiam.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_simsiam
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 122                 rbfn      simsiam                           2
# 130                 rbfn      simsiam                           2
# 128                 rbfn      simsiam                           2
# 120                 rbfn      simsiam                           2
# 138                 rbfn      simsiam                           2
# 126                 rbfn      simsiam                           2
# 121                 rbfn      simsiam                           2
# 127                 rbfn      simsiam                           2
# 143                 rbfn      simsiam                           2
# 141                 rbfn      simsiam                           2
# 142                 rbfn      simsiam                           2
# 129                 rbfn      simsiam                           2
# 135                 rbfn      simsiam                           2
# 134                 rbfn      simsiam                           2
# 139                 rbfn      simsiam                           2
# 133                 rbfn      simsiam                           2
# 137                 rbfn      simsiam                           2
# 131                 rbfn      simsiam                           2
# 136                 rbfn      simsiam                           2
# 125                 rbfn      simsiam                           2
# 123                 rbfn      simsiam                           2
# 124                 rbfn      simsiam                           2
# 132                 rbfn      simsiam                           2
# 140                 rbfn      simsiam                           2
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 122                               128                         multiquadric
# 130                               256                         multiquadric
# 128                               256                                  tps
# 120                               128                                  tps
# 138                               512                         multiquadric
# 126                               128                             gaussian
# 121                               128                                  tps
# 127                               128                             gaussian
# 143                               512                             gaussian
# 141                               512                 inverse_multiquadric
# 142                               512                             gaussian
# 129                               256                                  tps
# 135                               256                             gaussian
# 134                               256                             gaussian
# 139                               512                         multiquadric
# 133                               256                 inverse_multiquadric
# 137                               512                                  tps
# 131                               256                         multiquadric
# 136                               512                                  tps
# 125                               128                 inverse_multiquadric
# 123                               128                         multiquadric
# 124                               128                 inverse_multiquadric
# 132                               256                 inverse_multiquadric
# 140                               512                 inverse_multiquadric
#
#      rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 122                           False                 0.921792
# 130                           False                 0.921792
# 128                           False                 0.921626
# 120                           False                 0.921600
# 138                           False                 0.921588
# 126                           False                 0.921400
# 121                            True                 0.921400
# 127                            True                 0.921400
# 143                            True                 0.921400
# 141                            True                 0.921400
# 142                           False                 0.921400
# 129                            True                 0.921400
# 135                            True                 0.921400
# 134                           False                 0.921400
# 139                            True                 0.921400
# 133                            True                 0.921400
# 137                            True                 0.921215
# 131                            True                 0.921196
# 136                           False                 0.921041
# 125                            True                 0.921029
# 123                            True                 0.921010
# 124                           False                 0.920825
# 132                           False                 0.920825
# 140                           False                 0.920825
#
#      test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 122                0.918584                  0.929613               0.921792
# 130                0.918584                  0.929613               0.921792
# 128                0.918470                  0.929579               0.921626
# 120                0.918401                  0.929393               0.921600
# 138                0.918391                  0.929461               0.921588
# 126                0.918170                  0.929051               0.921400
# 121                0.918164                  0.929047               0.921400
# 127                0.918170                  0.929051               0.921400
# 143                0.918170                  0.929051               0.921400
# 141                0.918170                  0.929051               0.921400
# 142                0.918170                  0.929051               0.921400
# 129                0.918170                  0.929051               0.921400
# 135                0.918170                  0.929051               0.921400
# 134                0.918170                  0.929051               0.921400
# 139                0.918170                  0.929051               0.921400
# 133                0.918173                  0.929074               0.921400
# 137                0.917975                  0.928835               0.921215
# 131                0.917987                  0.928910               0.921196
# 136                0.917875                  0.928997               0.921041
# 125                0.917788                  0.928646               0.921029
# 123                0.917789                  0.928671               0.921010
# 124                0.917602                  0.928482               0.920825
# 132                0.917602                  0.928482               0.920825
# 140                0.917591                  0.928450               0.920825

# %% [markdown]
# #### MoCo

# %%
df_rbfn_moco = df_rbfn[df_rbfn["architecture"] == "moco"]
df_rbfn_moco = df_rbfn_moco.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_moco
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 116                 rbfn         moco                           2
# 100                 rbfn         moco                           2
# 108                 rbfn         moco                           2
# 96                  rbfn         moco                           2
# 104                 rbfn         moco                           2
# 49                  rbfn         moco                           4
# 53                  rbfn         moco                           4
# 50                  rbfn         moco                           4
# 115                 rbfn         moco                           2
# 101                 rbfn         moco                           2
# 98                  rbfn         moco                           2
# 106                 rbfn         moco                           2
# 52                  rbfn         moco                           4
# 58                  rbfn         moco                           4
# 66                  rbfn         moco                           4
# 61                  rbfn         moco                           4
# 80                  rbfn         moco                           3
# 81                  rbfn         moco                           3
# 83                  rbfn         moco                           3
# 65                  rbfn         moco                           4
# 76                  rbfn         moco                           3
# 75                  rbfn         moco                           3
# 84                  rbfn         moco                           3
# 85                  rbfn         moco                           3
# 99                  rbfn         moco                           2
# 89                  rbfn         moco                           3
# 97                  rbfn         moco                           2
# 77                  rbfn         moco                           3
# 107                 rbfn         moco                           2
# 109                 rbfn         moco                           2
# 113                 rbfn         moco                           2
# 105                 rbfn         moco                           2
# 93                  rbfn         moco                           3
# 73                  rbfn         moco                           3
# 114                 rbfn         moco                           2
# 117                 rbfn         moco                           2
# 74                  rbfn         moco                           3
# 54                  rbfn         moco                           4
# 48                  rbfn         moco                           4
# 51                  rbfn         moco                           4
# 55                  rbfn         moco                           4
# 86                  rbfn         moco                           3
# 87                  rbfn         moco                           3
# 79                  rbfn         moco                           3
# 78                  rbfn         moco                           3
# 72                  rbfn         moco                           3
# 57                  rbfn         moco                           4
# 56                  rbfn         moco                           4
# 63                  rbfn         moco                           4
# 62                  rbfn         moco                           4
# 64                  rbfn         moco                           4
# 67                  rbfn         moco                           4
# 68                  rbfn         moco                           4
# 69                  rbfn         moco                           4
# 70                  rbfn         moco                           4
# 71                  rbfn         moco                           4
# 60                  rbfn         moco                           4
# 59                  rbfn         moco                           4
# 82                  rbfn         moco                           3
# 88                  rbfn         moco                           3
# 91                  rbfn         moco                           3
# 92                  rbfn         moco                           3
# 94                  rbfn         moco                           3
# 95                  rbfn         moco                           3
# 103                 rbfn         moco                           2
# 102                 rbfn         moco                           2
# 90                  rbfn         moco                           3
# 110                 rbfn         moco                           2
# 111                 rbfn         moco                           2
# 118                 rbfn         moco                           2
# 119                 rbfn         moco                           2
# 112                 rbfn         moco                           2
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 116                               512                 inverse_multiquadric
# 100                               128                 inverse_multiquadric
# 108                               256                 inverse_multiquadric
# 96                                128                                  tps
# 104                               256                                  tps
# 49                                128                                  tps
# 53                                128                 inverse_multiquadric
# 50                                128                         multiquadric
# 115                               512                         multiquadric
# 101                               128                 inverse_multiquadric
# 98                                128                         multiquadric
# 106                               256                         multiquadric
# 52                                128                 inverse_multiquadric
# 58                                256                         multiquadric
# 66                                512                         multiquadric
# 61                                256                 inverse_multiquadric
# 80                                256                                  tps
# 81                                256                                  tps
# 83                                256                         multiquadric
# 65                                512                                  tps
# 76                                128                 inverse_multiquadric
# 75                                128                         multiquadric
# 84                                256                 inverse_multiquadric
# 85                                256                 inverse_multiquadric
# 99                                128                         multiquadric
# 89                                512                                  tps
# 97                                128                                  tps
# 77                                128                 inverse_multiquadric
# 107                               256                         multiquadric
# 109                               256                 inverse_multiquadric
# 113                               512                                  tps
# 105                               256                                  tps
# 93                                512                 inverse_multiquadric
# 73                                128                                  tps
# 114                               512                         multiquadric
# 117                               512                 inverse_multiquadric
# 74                                128                         multiquadric
# 54                                128                             gaussian
# 48                                128                                  tps
# 51                                128                         multiquadric
# 55                                128                             gaussian
# 86                                256                             gaussian
# 87                                256                             gaussian
# 79                                128                             gaussian
# 78                                128                             gaussian
# 72                                128                                  tps
# 57                                256                                  tps
# 56                                256                                  tps
# 63                                256                             gaussian
# 62                                256                             gaussian
# 64                                512                                  tps
# 67                                512                         multiquadric
# 68                                512                 inverse_multiquadric
# 69                                512                 inverse_multiquadric
# 70                                512                             gaussian
# 71                                512                             gaussian
# 60                                256                 inverse_multiquadric
# 59                                256                         multiquadric
# 82                                256                         multiquadric
# 88                                512                                  tps
# 91                                512                         multiquadric
# 92                                512                 inverse_multiquadric
# 94                                512                             gaussian
# 95                                512                             gaussian
# 103                               128                             gaussian
# 102                               128                             gaussian
# 90                                512                         multiquadric
# 110                               256                             gaussian
# 111                               256                             gaussian
# 118                               512                             gaussian
# 119                               512                             gaussian
# 112                               512                                  tps
#
#      rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 116                           False                 0.924116
# 100                           False                 0.924116
# 108                           False                 0.924116
# 96                            False                 0.924112
# 104                           False                 0.924112
# 49                             True                 0.924092
# 53                             True                 0.924092
# 50                            False                 0.924092
# 115                            True                 0.924092
# 101                            True                 0.924092
# 98                            False                 0.924092
# 106                           False                 0.924092
# 52                            False                 0.924092
# 58                            False                 0.924092
# 66                            False                 0.924092
# 61                             True                 0.924092
# 80                            False                 0.924092
# 81                             True                 0.924092
# 83                             True                 0.924092
# 65                             True                 0.924092
# 76                            False                 0.924092
# 75                             True                 0.924092
# 84                            False                 0.924092
# 85                             True                 0.924092
# 99                             True                 0.924092
# 89                             True                 0.924092
# 97                             True                 0.924092
# 77                             True                 0.924092
# 107                            True                 0.924092
# 109                            True                 0.924092
# 113                            True                 0.924092
# 105                            True                 0.924092
# 93                             True                 0.924092
# 73                             True                 0.924092
# 114                           False                 0.924092
# 117                            True                 0.924092
# 74                            False                 0.924092
# 54                            False                 0.923907
# 48                            False                 0.923907
# 51                             True                 0.923907
# 55                             True                 0.923907
# 86                            False                 0.923907
# 87                             True                 0.923907
# 79                             True                 0.923907
# 78                            False                 0.923907
# 72                            False                 0.923907
# 57                             True                 0.923907
# 56                            False                 0.923907
# 63                             True                 0.923907
# 62                            False                 0.923907
# 64                            False                 0.923907
# 67                             True                 0.923907
# 68                            False                 0.923907
# 69                             True                 0.923907
# 70                            False                 0.923907
# 71                             True                 0.923907
# 60                            False                 0.923907
# 59                             True                 0.923907
# 82                            False                 0.923907
# 88                            False                 0.923907
# 91                             True                 0.923907
# 92                            False                 0.923907
# 94                            False                 0.923907
# 95                             True                 0.923907
# 103                            True                 0.923907
# 102                           False                 0.923907
# 90                            False                 0.923907
# 110                           False                 0.923907
# 111                            True                 0.923907
# 118                           False                 0.923907
# 119                            True                 0.923907
# 112                           False                 0.923904
#
#      test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 116                0.921144                  0.931350               0.924116
# 100                0.921144                  0.931350               0.924116
# 108                0.921144                  0.931350               0.924116
# 96                 0.921111                  0.931251               0.924112
# 104                0.921111                  0.931251               0.924112
# 49                 0.921077                  0.931236               0.924092
# 53                 0.921077                  0.931236               0.924092
# 50                 0.921077                  0.931236               0.924092
# 115                0.921077                  0.931236               0.924092
# 101                0.921077                  0.931236               0.924092
# 98                 0.921077                  0.931236               0.924092
# 106                0.921077                  0.931236               0.924092
# 52                 0.921077                  0.931236               0.924092
# 58                 0.921077                  0.931236               0.924092
# 66                 0.921077                  0.931236               0.924092
# 61                 0.921077                  0.931236               0.924092
# 80                 0.921077                  0.931236               0.924092
# 81                 0.921077                  0.931236               0.924092
# 83                 0.921077                  0.931236               0.924092
# 65                 0.921077                  0.931236               0.924092
# 76                 0.921077                  0.931236               0.924092
# 75                 0.921077                  0.931236               0.924092
# 84                 0.921077                  0.931236               0.924092
# 85                 0.921077                  0.931236               0.924092
# 99                 0.921077                  0.931236               0.924092
# 89                 0.921077                  0.931236               0.924092
# 97                 0.921077                  0.931236               0.924092
# 77                 0.921077                  0.931236               0.924092
# 107                0.921077                  0.931236               0.924092
# 109                0.921077                  0.931236               0.924092
# 113                0.921077                  0.931236               0.924092
# 105                0.921077                  0.931236               0.924092
# 93                 0.921077                  0.931236               0.924092
# 73                 0.921077                  0.931236               0.924092
# 114                0.921077                  0.931236               0.924092
# 117                0.921077                  0.931236               0.924092
# 74                 0.921077                  0.931236               0.924092
# 54                 0.920894                  0.931050               0.923907
# 48                 0.920894                  0.931050               0.923907
# 51                 0.920894                  0.931050               0.923907
# 55                 0.920894                  0.931050               0.923907
# 86                 0.920894                  0.931050               0.923907
# 87                 0.920894                  0.931050               0.923907
# 79                 0.920894                  0.931050               0.923907
# 78                 0.920894                  0.931050               0.923907
# 72                 0.920894                  0.931050               0.923907
# 57                 0.920894                  0.931050               0.923907
# 56                 0.920894                  0.931050               0.923907
# 63                 0.920894                  0.931050               0.923907
# 62                 0.920894                  0.931050               0.923907
# 64                 0.920894                  0.931050               0.923907
# 67                 0.920894                  0.931050               0.923907
# 68                 0.920894                  0.931050               0.923907
# 69                 0.920894                  0.931050               0.923907
# 70                 0.920894                  0.931050               0.923907
# 71                 0.920894                  0.931050               0.923907
# 60                 0.920894                  0.931050               0.923907
# 59                 0.920894                  0.931050               0.923907
# 82                 0.920894                  0.931050               0.923907
# 88                 0.920894                  0.931050               0.923907
# 91                 0.920894                  0.931050               0.923907
# 92                 0.920894                  0.931050               0.923907
# 94                 0.920894                  0.931050               0.923907
# 95                 0.920894                  0.931050               0.923907
# 103                0.920894                  0.931050               0.923907
# 102                0.920894                  0.931050               0.923907
# 90                 0.920894                  0.931050               0.923907
# 110                0.920894                  0.931050               0.923907
# 111                0.920894                  0.931050               0.923907
# 118                0.920894                  0.931050               0.923907
# 119                0.920894                  0.931050               0.923907
# 112                0.920895                  0.931059               0.923904

# %% [markdown]
# #### BYOL

# %%
df_rbfn_byol = df_rbfn[df_rbfn["architecture"] == "byol"]
df_rbfn_byol = df_rbfn_byol.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_byol
# Out:
#    projection_head_type architecture  projection_head_num_layers  \
# 30                 rbfn         byol                           2
# 31                 rbfn         byol                           2
# 39                 rbfn         byol                           2
# 38                 rbfn         byol                           2
# 46                 rbfn         byol                           2
# 47                 rbfn         byol                           2
# 24                 rbfn         byol                           2
# 25                 rbfn         byol                           2
# 28                 rbfn         byol                           2
# 29                 rbfn         byol                           2
# 26                 rbfn         byol                           2
# 27                 rbfn         byol                           2
# 35                 rbfn         byol                           2
# 34                 rbfn         byol                           2
# 32                 rbfn         byol                           2
# 33                 rbfn         byol                           2
# 36                 rbfn         byol                           2
# 37                 rbfn         byol                           2
# 40                 rbfn         byol                           2
# 41                 rbfn         byol                           2
# 43                 rbfn         byol                           2
# 42                 rbfn         byol                           2
# 45                 rbfn         byol                           2
# 44                 rbfn         byol                           2
#
#     rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 30                               128                             gaussian
# 31                               128                             gaussian
# 39                               256                             gaussian
# 38                               256                             gaussian
# 46                               512                             gaussian
# 47                               512                             gaussian
# 24                               128                                  tps
# 25                               128                                  tps
# 28                               128                 inverse_multiquadric
# 29                               128                 inverse_multiquadric
# 26                               128                         multiquadric
# 27                               128                         multiquadric
# 35                               256                         multiquadric
# 34                               256                         multiquadric
# 32                               256                                  tps
# 33                               256                                  tps
# 36                               256                 inverse_multiquadric
# 37                               256                 inverse_multiquadric
# 40                               512                                  tps
# 41                               512                                  tps
# 43                               512                         multiquadric
# 42                               512                         multiquadric
# 45                               512                 inverse_multiquadric
# 44                               512                 inverse_multiquadric
#
#     rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 30                           False                 0.921058
# 31                            True                 0.921058
# 39                            True                 0.921058
# 38                           False                 0.921058
# 46                           False                 0.921058
# 47                            True                 0.921058
# 24                           False                 0.010000
# 25                            True                 0.010000
# 28                           False                 0.010000
# 29                            True                 0.010000
# 26                           False                 0.010000
# 27                            True                 0.010000
# 35                            True                 0.010000
# 34                           False                 0.010000
# 32                           False                 0.010000
# 33                            True                 0.010000
# 36                           False                 0.010000
# 37                            True                 0.010000
# 40                           False                 0.010000
# 41                            True                 0.010000
# 43                            True                 0.010000
# 42                           False                 0.010000
# 45                            True                 0.010000
# 44                           False                 0.010000
#
#     test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 30                0.917884                  0.928891               0.921058
# 31                0.917884                  0.928891               0.921058
# 39                0.917884                  0.928891               0.921058
# 38                0.917884                  0.928891               0.921058
# 46                0.917884                  0.928891               0.921058
# 47                0.917884                  0.928891               0.921058
# 24                0.000203                  0.000102               0.010000
# 25                0.000203                  0.000102               0.010000
# 28                0.000203                  0.000102               0.010000
# 29                0.000203                  0.000102               0.010000
# 26                0.000203                  0.000102               0.010000
# 27                0.000203                  0.000102               0.010000
# 35                0.000203                  0.000102               0.010000
# 34                0.000203                  0.000102               0.010000
# 32                0.000203                  0.000102               0.010000
# 33                0.000203                  0.000102               0.010000
# 36                0.000203                  0.000102               0.010000
# 37                0.000203                  0.000102               0.010000
# 40                0.000203                  0.000102               0.010000
# 41                0.000203                  0.000102               0.010000
# 43                0.000203                  0.000102               0.010000
# 42                0.000203                  0.000102               0.010000
# 45                0.000203                  0.000102               0.010000
# 44                0.000203                  0.000102               0.010000

# %% [markdown]
# #### SwAV

# %%
df_rbfn_swav = df_rbfn[df_rbfn["architecture"] == "swav"]
df_rbfn_swav = df_rbfn_swav.sort_values(by=MAIN_METRIC, ascending=False)
df_rbfn_swav
# Out:
#    projection_head_type architecture  projection_head_num_layers  \
# 6                  rbfn         swav                           2
# 7                  rbfn         swav                           2
# 15                 rbfn         swav                           2
# 14                 rbfn         swav                           2
# 22                 rbfn         swav                           2
# 23                 rbfn         swav                           2
# 8                  rbfn         swav                           2
# 0                  rbfn         swav                           2
# 16                 rbfn         swav                           2
# 2                  rbfn         swav                           2
# 18                 rbfn         swav                           2
# 1                  rbfn         swav                           2
# 10                 rbfn         swav                           2
# 9                  rbfn         swav                           2
# 3                  rbfn         swav                           2
# 17                 rbfn         swav                           2
# 5                  rbfn         swav                           2
# 13                 rbfn         swav                           2
# 11                 rbfn         swav                           2
# 4                  rbfn         swav                           2
# 12                 rbfn         swav                           2
# 19                 rbfn         swav                           2
# 21                 rbfn         swav                           2
# 20                 rbfn         swav                           2
#
#     rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 6                                128                             gaussian
# 7                                128                             gaussian
# 15                               256                             gaussian
# 14                               256                             gaussian
# 22                               512                             gaussian
# 23                               512                             gaussian
# 8                                256                                  tps
# 0                                128                                  tps
# 16                               512                                  tps
# 2                                128                         multiquadric
# 18                               512                         multiquadric
# 1                                128                                  tps
# 10                               256                         multiquadric
# 9                                256                                  tps
# 3                                128                         multiquadric
# 17                               512                                  tps
# 5                                128                 inverse_multiquadric
# 13                               256                 inverse_multiquadric
# 11                               256                         multiquadric
# 4                                128                 inverse_multiquadric
# 12                               256                 inverse_multiquadric
# 19                               512                         multiquadric
# 21                               512                 inverse_multiquadric
# 20                               512                 inverse_multiquadric
#
#     rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 6                            False                 0.888497
# 7                             True                 0.888497
# 15                            True                 0.888497
# 14                           False                 0.888497
# 22                           False                 0.888497
# 23                            True                 0.888497
# 8                            False                 0.869291
# 0                            False                 0.867992
# 16                           False                 0.856663
# 2                            False                 0.848601
# 18                           False                 0.814041
# 1                             True                 0.709717
# 10                           False                 0.693065
# 9                             True                 0.552745
# 3                             True                 0.418808
# 17                            True                 0.313091
# 5                             True                 0.275960
# 13                            True                 0.170720
# 11                            True                 0.053374
# 4                            False                 0.010000
# 12                           False                 0.010000
# 19                            True                 0.010000
# 21                            True                 0.010000
# 20                           False                 0.010000
#
#     test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 6                 0.885746                  0.896659               0.888497
# 7                 0.885746                  0.896659               0.888497
# 15                0.885746                  0.896659               0.888497
# 14                0.885746                  0.896659               0.888497
# 22                0.885746                  0.896659               0.888497
# 23                0.885746                  0.896659               0.888497
# 8                 0.866401                  0.883001               0.869291
# 0                 0.865770                  0.880266               0.867992
# 16                0.852587                  0.861257               0.856663
# 2                 0.846190                  0.856425               0.848601
# 18                0.808568                  0.834901               0.814041
# 1                 0.691311                  0.736161               0.709717
# 10                0.667200                  0.751717               0.693065
# 9                 0.514743                  0.621367               0.552745
# 3                 0.379863                  0.540548               0.418808
# 17                0.299579                  0.468855               0.313091
# 5                 0.242296                  0.368632               0.275960
# 13                0.112152                  0.160790               0.170720
# 11                0.030476                  0.092015               0.053374
# 4                 0.000203                  0.000102               0.010000
# 12                0.000203                  0.000102               0.010000
# 19                0.000203                  0.000102               0.010000
# 21                0.000203                  0.000102               0.010000
# 20                0.000203                  0.000102               0.010000

# %% [markdown]
# ## Comparison by Architecture

# %% [markdown]
# ### Top-1 Accuracy

# %%
METRIC_COL = "test_MulticlassAccuracy"

# %% [markdown]
# #### SimCLR

# %%
df_default_rbfn_simclr = pd.concat([df_default_simclr.head(1), df_rbfn_simclr.head(1)])
df_default_rbfn_simclr
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 6                default       simclr                           4
# 144                 rbfn       simclr                           4
#
#      test_MulticlassAccuracy  test_MulticlassF1Score  \
# 6                   0.883743                0.883998
# 144                 0.921659                0.918458
#
#      test_MulticlassPrecision  test_MulticlassRecall  \
# 6                    0.888626               0.883743
# 144                  0.929467               0.921659
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 6                                 NaN                                  NaN
# 144                             128.0                                  tps
#
#     rbfn_projection_head_normalize
# 6                              NaN
# 144                          False

# %%
rbfn_default_diff_simclr = df_default_rbfn_simclr[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_simclr * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): 3.79 %

# %% [markdown]
# #### SimSiam

# %%
df_default_rbfn_simsiam = pd.concat([df_default_simsiam.head(1), df_rbfn_simsiam.head(1)])
df_default_rbfn_simsiam
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 5                default      simsiam                           2
# 122                 rbfn      simsiam                           2
#
#      test_MulticlassAccuracy  test_MulticlassF1Score  \
# 5                   0.920327                0.920830
# 122                 0.921792                0.918584
#
#      test_MulticlassPrecision  test_MulticlassRecall  \
# 5                    0.925832               0.920327
# 122                  0.929613               0.921792
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 5                                 NaN                                  NaN
# 122                             128.0                         multiquadric
#
#     rbfn_projection_head_normalize
# 5                              NaN
# 122                          False

# %%
rbfn_default_diff_simsiam = df_default_rbfn_simsiam[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_simsiam * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): 0.15 %

# %% [markdown]
# #### MoCo

# %%
df_default_rbfn_moco = pd.concat([df_default_moco.head(1), df_rbfn_moco.head(1)])
df_default_rbfn_moco.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_default_rbfn_moco
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 116                 rbfn         moco                           2
# 2                default         moco                           4
#
#      test_MulticlassAccuracy  test_MulticlassF1Score  \
# 116                 0.924116                0.921144
# 2                   0.919822                0.920365
#
#      test_MulticlassPrecision  test_MulticlassRecall  \
# 116                   0.93135               0.924116
# 2                     0.92426               0.919822
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 116                             512.0                 inverse_multiquadric
# 2                                 NaN                                  NaN
#
#     rbfn_projection_head_normalize
# 116                          False
# 2                              NaN

# %%
rbfn_default_diff_moco = df_default_rbfn_moco[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_moco * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): -0.43 %

# %% [markdown]
# #### BYOL

# %%
df_default_rbfn_byol = pd.concat([df_default_byol.head(1), df_rbfn_byol.head(1)])
df_default_rbfn_byol.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_default_rbfn_byol
# Out:
#    projection_head_type architecture  projection_head_num_layers  \
# 30                 rbfn         byol                           2
# 1               default         byol                           2
#
#     test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 30                 0.921058                0.917884                  0.928891
# 1                  0.889295                0.884485                  0.895701
#
#     test_MulticlassRecall  rbfn_projection_head_num_kernels  \
# 30               0.921058                             128.0
# 1                0.889295                               NaN
#
#    rbfn_projection_head_radial_function rbfn_projection_head_normalize
# 30                             gaussian                          False
# 1                                   NaN                            NaN

# %%
rbfn_default_diff_byol = df_default_rbfn_byol[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_byol * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): -3.18 %

# %% [markdown]
# #### SwAV

# %%
df_default_rbfn_swav = pd.concat([df_default_swav.head(1), df_rbfn_swav.head(1)])
df_default_rbfn_swav.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_default_rbfn_swav
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 6                 rbfn         swav                           2
# 0              default         swav                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 6                 0.888497                0.885746                  0.896659
# 0                 0.876979                0.875282                  0.885032
#
#    test_MulticlassRecall  rbfn_projection_head_num_kernels  \
# 6               0.888497                             128.0
# 0               0.876979                               NaN
#
#   rbfn_projection_head_radial_function rbfn_projection_head_normalize
# 6                             gaussian                          False
# 0                                  NaN                            NaN

# %%
rbfn_default_diff_swav = df_default_rbfn_swav[METRIC_COL].diff().iloc[-1]
print(f"Delta RBFN <-> Default ({METRIC_COL}):", round(rbfn_default_diff_swav * 100, 2), "%")
# Out:
# Delta RBFN <-> Default (test_MulticlassAccuracy): -1.15 %

# %% [markdown]
# #### Peak Performance Across Architectures

# %%
df_default_best = pd.concat([
    df_default_simclr.head(1),
    df_default_simsiam.head(1),
    df_default_moco.head(1),
    df_default_byol.head(1),
    df_default_swav.head(1)  
])
df_default_best.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_default_best
# Out:
#   projection_head_type architecture  projection_head_num_layers  \
# 5              default      simsiam                           2
# 2              default         moco                           4
# 1              default         byol                           2
# 6              default       simclr                           4
# 0              default         swav                           2
#
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 5                 0.920327                0.920830                  0.925832
# 2                 0.919822                0.920365                  0.924260
# 1                 0.889295                0.884485                  0.895701
# 6                 0.883743                0.883998                  0.888626
# 0                 0.876979                0.875282                  0.885032
#
#    test_MulticlassRecall
# 5               0.920327
# 2               0.919822
# 1               0.889295
# 6               0.883743
# 0               0.876979

# %%
df_default_best[METRICS].mean()
# Out:
# test_MulticlassAccuracy     0.898033
# test_MulticlassF1Score      0.896992
# test_MulticlassPrecision    0.903890
# test_MulticlassRecall       0.898033
# dtype: float64

# %%
default_best_mean = df_default_best[[METRIC_COL]].mean().iloc[-1]
print(f"Mean {METRIC_COL} (default):", round(default_best_mean * 100, 2), "%")
# Out:
# Mean test_MulticlassAccuracy (default): 89.8 %

# %%
df_rbfn_best = pd.concat([
    df_rbfn_simclr.head(1),
    df_rbfn_simsiam.head(1),
    df_rbfn_moco.head(1),
    df_rbfn_byol.head(1),
    df_rbfn_swav.head(1)
])
df_rbfn_best.sort_values(by=METRIC_COL, ascending=False, inplace=True)
df_rbfn_best
# Out:
#     projection_head_type architecture  projection_head_num_layers  \
# 116                 rbfn         moco                           2
# 122                 rbfn      simsiam                           2
# 144                 rbfn       simclr                           4
# 30                  rbfn         byol                           2
# 6                   rbfn         swav                           2
#
#      rbfn_projection_head_num_kernels rbfn_projection_head_radial_function  \
# 116                               512                 inverse_multiquadric
# 122                               128                         multiquadric
# 144                               128                                  tps
# 30                                128                             gaussian
# 6                                 128                             gaussian
#
#      rbfn_projection_head_normalize  test_MulticlassAccuracy  \
# 116                           False                 0.924116
# 122                           False                 0.921792
# 144                           False                 0.921659
# 30                            False                 0.921058
# 6                             False                 0.888497
#
#      test_MulticlassF1Score  test_MulticlassPrecision  test_MulticlassRecall
# 116                0.921144                  0.931350               0.924116
# 122                0.918584                  0.929613               0.921792
# 144                0.918458                  0.929467               0.921659
# 30                 0.917884                  0.928891               0.921058
# 6                  0.885746                  0.896659               0.888497

# %%
df_rbfn_best[METRICS].mean()
# Out:
# test_MulticlassAccuracy     0.915424
# test_MulticlassF1Score      0.912363
# test_MulticlassPrecision    0.923196
# test_MulticlassRecall       0.915424
# dtype: float64

# %%
rbfn_best_mean = df_rbfn_best[[METRIC_COL]].mean().iloc[-1]
print(f"Mean {METRIC_COL} (RBFN):", round(rbfn_best_mean * 100, 2), "%")
# Out:
# Mean test_MulticlassAccuracy (RBFN): 91.54 %

# %%
print(f"Diff. mean {METRIC_COL} RBFN <-> default:", round((rbfn_best_mean - default_best_mean) * 100, 2), "%")
# Out:
# Diff. mean test_MulticlassAccuracy RBFN <-> default: 1.74 %

# %%
#### Average Performance Across Architectures

# %%
df_default_average = pd.concat([
    df_default_moco[METRICS].mean().to_frame().T.assign(architecture="moco", projection_head_type="default"),
    df_default_simclr[METRICS].mean().to_frame().T.assign(architecture="simclr", projection_head_type="default"),
    df_default_byol[METRICS].mean().to_frame().T.assign(architecture="byol", projection_head_type="default"),
    df_default_swav[METRICS].mean().to_frame().T.assign(architecture="swav", projection_head_type="default"),
    df_default_simsiam[METRICS].mean().to_frame().T.assign(architecture="simsiam", projection_head_type="default"),
], ignore_index=True)

df_default_average
# Out:
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 0                 0.917438                0.917984                  0.921902
# 1                 0.880652                0.880912                  0.885819
# 2                 0.889295                0.884485                  0.895701
# 3                 0.876979                0.875282                  0.885032
# 4                 0.920327                0.920830                  0.925832
#
#    test_MulticlassRecall architecture projection_head_type
# 0               0.917438         moco              default
# 1               0.880652       simclr              default
# 2               0.889295         byol              default
# 3               0.876979         swav              default
# 4               0.920327      simsiam              default

# %%
df_default_average[METRICS].mean()
# Out:
# test_MulticlassAccuracy     0.896938
# test_MulticlassF1Score      0.895899
# test_MulticlassPrecision    0.902857
# test_MulticlassRecall       0.896938
# dtype: float64

# %%
df_rbfn_average = pd.concat([
    df_rbfn_moco[METRICS].mean().to_frame().T.assign(architecture="moco", projection_head_type="rbfn"),
    df_rbfn_simclr[METRICS].mean().to_frame().T.assign(architecture="simclr", projection_head_type="rbfn"),
    df_rbfn_byol[METRICS].mean().to_frame().T.assign(architecture="byol", projection_head_type="rbfn"),
    df_rbfn_swav[METRICS].mean().to_frame().T.assign(architecture="swav", projection_head_type="rbfn"),
    df_rbfn_simsiam[METRICS].mean().to_frame().T.assign(architecture="simsiam", projection_head_type="rbfn"),
], ignore_index=True)

df_rbfn_average
# Out:
#    test_MulticlassAccuracy  test_MulticlassF1Score  test_MulticlassPrecision  \
# 0                 0.924004                0.920992                  0.931151
# 1                 0.600344                0.591864                  0.612728
# 2                 0.237764                0.229623                  0.232300
# 3                 0.534377                0.520526                  0.559850
# 4                 0.921323                0.918105                  0.929029
#
#    test_MulticlassRecall architecture projection_head_type
# 0               0.924004         moco                 rbfn
# 1               0.600344       simclr                 rbfn
# 2               0.237764         byol                 rbfn
# 3               0.534377         swav                 rbfn
# 4               0.921323      simsiam                 rbfn

# %%
df_rbfn_average[METRICS].mean()
# Out:
# test_MulticlassAccuracy     0.643563
# test_MulticlassF1Score      0.636222
# test_MulticlassPrecision    0.653012
# test_MulticlassRecall       0.643563
# dtype: float64

# %% [markdown]
# ### SHAP Analysis of RBFN Parameters

# %%
X = df_rbfn.drop(columns=[
    MAIN_METRIC,
    "test_MulticlassF1Score",
    "test_MulticlassPrecision",
    "test_MulticlassRecall",
    "projection_head_type",
    "architecture"])
y = df_rbfn[MAIN_METRIC]

# %%
X = pd.get_dummies(X, drop_first=False)
bool_cols = X.select_dtypes(include=["bool"]).columns
X[bool_cols] = X[bool_cols].astype(int)

# %%
xgb_model = XGBRegressor()
xgb_model.fit(X, y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
explainer = shap.Explainer(xgb_model, X)
shap_values = explainer(X)

# %%
shap_df = pd.DataFrame(shap_values.values, columns=X.columns)
importance_table = pd.DataFrame({
    "mean_abs_shap": shap_df.abs().mean(),
    "positive_mean": shap_df.where(shap_df > 0).mean(),
    "negative_mean": shap_df.where(shap_df < 0).mean(),
    "std": shap_df.std()
})
importance_table = importance_table.sort_values("mean_abs_shap", ascending=False)
importance_table.round(2)
# Out:
#                                                     mean_abs_shap  \
# rbfn_projection_head_radial_function_gaussian                0.11
# projection_head_num_layers                                   0.04
# rbfn_projection_head_normalize                               0.04
# rbfn_projection_head_radial_function_inverse_mu...           0.03
# rbfn_projection_head_radial_function_tps                     0.02
# rbfn_projection_head_num_kernels                             0.02
# rbfn_projection_head_radial_function_multiquadric            0.00
#
#                                                     positive_mean  \
# rbfn_projection_head_radial_function_gaussian                0.22
# projection_head_num_layers                                   0.08
# rbfn_projection_head_normalize                               0.03
# rbfn_projection_head_radial_function_inverse_mu...           0.02
# rbfn_projection_head_radial_function_tps                     0.05
# rbfn_projection_head_num_kernels                             0.02
# rbfn_projection_head_radial_function_multiquadric            0.00
#
#                                                     negative_mean   std
# rbfn_projection_head_radial_function_gaussian               -0.07  0.13
# projection_head_num_layers                                  -0.03  0.07
# rbfn_projection_head_normalize                              -0.04  0.05
# rbfn_projection_head_radial_function_inverse_mu...          -0.06  0.04
# rbfn_projection_head_radial_function_tps                    -0.02  0.04
# rbfn_projection_head_num_kernels                            -0.02  0.02
# rbfn_projection_head_radial_function_multiquadric           -0.00  0.00

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)
